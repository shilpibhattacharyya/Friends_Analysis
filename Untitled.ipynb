# %%
import pandas as pd

# %%
df=pd.read_csv("../../Downloads/nyc-inspections/DOHMH_New_York_City_Restaurant_Inspection_Results.csv")

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df=df[['DBA','VIOLATION DESCRIPTION','CUISINE DESCRIPTION','BORO']]

# %%
df.head(50)
# Out:
#                                          DBA  \
# 0   NOTARO RESTAURANT
# 1   NOTARO RESTAURANT
# 2   VITE BAR
# 3   TACK'S CHINESE TAKE OUT
# 4   NO QUARTER
# 5   KABAB HOUSE NYC
# 6   HENRI'S BACKYARD
# 7   RICHMOND COUNTY COUNTRY CLUB
# 8   PLANET WINGS
# 9   TOMOE SUSHI
# 10  YAKITORI TAISHO
# 11  GOLDEN KRUST CARIBBEAN BAKERY & GRILL
# 12  CRAB SPOT RESTAURANT
# 13  M NOODLE SHOP
# 14  LOWER SUITES STOLI BAR SOUTH CLUB LOUNGE
# 15  AN BEAL BOCHT CAFE
# 16  NOM WAH TEA/DIM SUM PALOR
# 17  LUIGI'S PIZZA & PASTA
# 18  ANARKALI INDIAN FOOD
# 19  MIDNIGHT EXPRESS
# 20  NEW PANDA GARDEN
# 21  SPRING FISH VILLAGE
# 22  SERVICE BAR 7
# 23  THE FIVE SPOT
# 24  MEZQUITE
# 25  EL RUMBERO BAR RESTAURANT
# 26  TROPICAL REVIVAL RESTAURANT & CATERING
# 27  ICHI UMI
# 28  BROOKLYN DINER
# 29  ANABLE BASIN SAILING
# 30  MR. WONTON
# 31  BAGEL WORLD
# 32  BEST EAST STAR RESTAURANT
# 33  HAPPY RESTAURANT
# 34  WOLF AND LAMB
# 35  KBBQ
# 36  JUMBO CHINESE KITCHEN
# 37  REGAL CINEMAS
# ...

# %%
df.count()
# Out:
# DBA                      399559
# VIOLATION DESCRIPTION    392939
# CUISINE DESCRIPTION      399918
# BORO                     399918
# dtype: int64

# %%
df[df['CUISINE DESCRIPTION'] == "Indian"].count()
# Out:
# DBA                      6184
# VIOLATION DESCRIPTION    6097
# CUISINE DESCRIPTION      6184
# BORO                     6184
# dtype: int64
