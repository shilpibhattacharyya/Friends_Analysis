# %%
# NOTE: PLEASE MAKE SURE YOU ARE RUNNING THIS IN A PYTHON3 ENVIRONMENT
#!pip install -q tensorflow
#!pip install tensorflow==2.0.0-beta0
# !conda update --all --yes
# !pip install --upgrade tensorflow==2.0.0-beta1
import tensorflow as tf
print(tf.__version__)

# This is needed for the iterator over the data
# But not necessary if you have TF 2.0 installed



tf.enable_eager_execution()
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /anaconda2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anaconda-navigator-1.9.7   |           py27_0         4.8 MB
#     atomicwrites-1.3.0         |           py27_1          12 KB
#     attrs-19.1.0               |           py27_1          56 KB
#     backports-1.0              |             py_2         139 KB
#     backports.functools_lru_cache-1.5|             py_2           9 KB
#     backports.tempfile-1.0     |             py_1          12 KB
#     backports.weakref-1.0.post1|             py_1           7 KB
#     beautifulsoup4-4.7.1       |           py27_1         139 KB
#     bleach-3.1.0               |           py27_0         228 KB
#     bokeh-1.3.1                |           py27_0         4.0 MB
#     bzip2-1.0.8                |       h1de35cc_0         104 KB
#     certifi-2019.6.16          |           py27_1         155 KB
#     cffi-1.12.3                |   py27hb5b8e2f_0         210 KB
#     chardet-3.0.4              |        py27_1003         184 KB
#     cloudpickle-1.2.1          |             py_0          28 KB
#     conda-4.7.10               |           py27_0         3.0 MB
#     conda-build-3.18.9         |           py27_0         531 KB
#     conda-verify-3.4.2         |             py_1          25 KB
#     configparser-3.7.4         |           py27_0          41 KB
#     cryptography-2.7           |   py27ha12b0ac_0         576 KB
#     cytoolz-0.10.0             |   py27h1de35cc_0         363 KB
#     dask-1.2.2                 |             py_0          11 KB
#     dask-core-1.2.2            |             py_0         539 KB
#     dbus-1.13.6                |       h90a0687_0         560 KB
#     defusedxml-0.6.0           |             py_0          23 KB
#     dill-0.3.0                 |           py27_0         115 KB
#     distributed-1.28.1         |           py27_0         858 KB
#     entrypoints-0.3            |           py27_0          11 KB
#     filelock-3.0.12            |             py_0          12 KB
#     futures-3.3.0              |           py27_0          28 KB
#     glob2-0.7                  |             py_0          14 KB
#     glue-core-0.14.2           |           py27_0         1.4 MB
#     h5py-2.9.0                 |   py27h3134771_0         928 KB
#     hdf5-1.10.4                |       hfa1e0ec_0         4.5 MB
#     imageio-2.5.0              |           py27_0         3.4 MB
#     importlib_metadata-0.17    |           py27_1          39 KB
#     intel-openmp-2019.4        |              233         1.1 MB
#     jinja2-2.10.1              |           py27_0         181 KB
#     jsonschema-3.0.1           |           py27_0          86 KB
#     jupyter_client-5.3.1       |             py_0          69 KB
#     jupyter_core-4.5.0         |             py_0          48 KB
#     kiwisolver-1.1.0           |   py27h0a44026_0          61 KB
#     liblief-0.9.0              |       h2a1bed3_2         4.0 MB
#     libpng-1.6.37              |       ha441bb4_0         325 KB
#     libtiff-4.0.10             |       hcb84e12_2         524 KB
#     libxml2-2.9.9              |       hf6e021a_1         1.9 MB
#     markupsafe-1.1.1           |   py27h1de35cc_0          27 KB
#     mkl-2019.4                 |              233       155.2 MB
#     mkl_fft-1.0.12             |   py27h5e564d8_0         154 KB
#     more-itertools-5.0.0       |           py27_0          86 KB
#     mpl-scatter-density-0.6    |             py_0         647 KB
#     msgpack-python-0.6.1       |   py27h04f5b5a_1          85 KB
#     nbconvert-5.5.0            |             py_0         381 KB
#     numpy-1.16.4               |   py27hacdab7b_0          49 KB
#     numpy-base-1.16.4          |   py27h6575580_0         4.2 MB
#     packaging-19.0             |           py27_0          37 KB
#     pandas-0.24.2              |   py27h0a44026_0        10.0 MB
#     pandoc-2.2.3.2             |                0        13.8 MB
#     partd-1.0.0                |             py_0          19 KB
#     pathlib2-2.3.4             |           py27_0          35 KB
#     pcre-8.43                  |       h0a44026_0         227 KB
#     pexpect-4.7.0              |           py27_0          79 KB
#     pillow-6.1.0               |   py27hb68e598_0         598 KB
#     pip-19.1.1                 |           py27_0         1.8 MB
#     pkginfo-1.5.0.1            |           py27_0          41 KB
#     plotly-4.0.0               |             py_0         3.8 MB
#     pluggy-0.12.0              |             py_0          20 KB
#     prometheus_client-0.7.1    |             py_0          42 KB
#     psutil-5.6.3               |   py27h1de35cc_0         328 KB
#     py-1.8.0                   |           py27_0         137 KB
#     py-lief-0.9.0              |   py27h1413db1_2         1.5 MB
#     pygments-2.4.2             |             py_0         664 KB
#     pyopenssl-19.0.0           |           py27_0          79 KB
#     pyparsing-2.4.0            |             py_0          58 KB
#     pyrsistent-0.14.11         |   py27h1de35cc_0          86 KB
#     pysocks-1.7.0              |           py27_0          29 KB
#     pytest-4.6.2               |           py27_0         358 KB
#     python-libarchive-c-2.8    |          py27_11          22 KB
#     pytz-2019.1                |             py_0         236 KB
#     pywavelets-1.0.3           |   py27h1d22016_1         4.3 MB
#     pyyaml-5.1.1               |   py27h1de35cc_0         166 KB
#     qtconsole-4.5.2            |             py_0          92 KB
#     qtpy-1.8.0                 |             py_0          38 KB
#     requests-2.22.0            |           py27_0          88 KB
#     scikit-image-0.14.2        |   py27h0a44026_0        23.2 MB
#     scipy-1.2.1                |   py27h1410ff5_0        15.7 MB
#     setuptools-41.0.1          |           py27_0         627 KB
#     soupsieve-1.9.2            |           py27_0          60 KB
#     sqlite-3.29.0              |       ha441bb4_0         2.4 MB
#     subprocess32-3.5.4         |   py27h1de35cc_0          47 KB
#     tblib-1.4.0                |             py_0          14 KB
#     terminado-0.8.2            |           py27_0          21 KB
#     toolz-0.10.0               |             py_0          50 KB
#     tqdm-4.32.1                |             py_0          48 KB
#     urllib3-1.24.2             |           py27_0         151 KB
#     wheel-0.33.4               |           py27_0          39 KB
#     zict-1.0.0                 |             py_0          12 KB
#     zipp-0.5.2                 |             py_0           8 KB
#     ------------------------------------------------------------
#                                            Total:       277.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   backports.tempfile pkgs/main/noarch::backports.tempfile-1.0-py_1
#   backports.weakref  pkgs/main/noarch::backports.weakref-1.0.post1-py_1
#   pyrsistent         pkgs/main/osx-64::pyrsistent-0.14.11-py27h1de35cc_0
#   soupsieve          pkgs/main/osx-64::soupsieve-1.9.2-py27_0
#   zipp               pkgs/main/noarch::zipp-0.5.2-py_0
#
# The following packages will be REMOVED:
#
#   alabaster-0.7.12-py27_0
#   anaconda-project-0.8.2-py27_0
#   appscript-1.0.1-py27h1de35cc_1
#   astroid-1.6.5-py27_0
#   babel-2.6.0-py27_0
#   backports.os-0.1.1-py27_0
#   bitarray-0.8.3-py27h1de35cc_0
#   bkcharts-0.2-py27haafc882_0
#   blaze-0.11.3-py27_0
#   blosc-1.14.4-hd9629dc_0
#   boto-2.49.0-py27_0
#   cdecimal-2.3-py27h1de35cc_3
#   colorama-0.4.1-py27_0
#   curl-7.63.0-ha441bb4_1000
#   cython-0.29.2-py27h0a44026_0
#   datashape-0.5.4-py27_1
#   docutils-0.14-py27h0befae3_0
#   et_xmlfile-1.0.1-py27hc42f929_0
#   fastcache-1.0.2-py27h1de35cc_2
#   flask-1.0.2-py27_1
#   flask-cors-3.0.7-py27_0
#   get_terminal_size-1.0.0-h7520d66_0
#   gevent-1.3.7-py27h1de35cc_1
#   gmp-6.1.2-hb37e062_1
#   gmpy2-2.0.8-py27h6ef4df4_2
#   greenlet-0.4.15-py27h1de35cc_0
#   grin-1.2.1-py27_4
#   html5lib-1.0.1-py27_0
#   imagesize-1.1.0-py27_0
#   isort-4.3.4-py27_0
#   itsdangerous-1.1.0-py27_0
#   jbig-2.1-h4d881f8_0
#   jdcal-1.4-py27_0
#   jedi-0.13.2-py27_0
#   keyring-17.0.0-py27_0
#   krb5-1.16.1-hddcf347_7
#   lazy-object-proxy-1.3.1-py27h1de35cc_2
#   libcurl-7.63.0-h051b688_1000
#   libssh2-1.8.0-ha12b0ac_4
#   libxslt-1.1.32-hb819dd2_0
#   llvmlite-0.26.0-py27h8c7ce04_0
#   lxml-4.2.5-py27hef8c89e_0
#   mccabe-0.6.1-py27_1
#   mkl-service-1.1.2-py27hfbe908c_5
#   mpc-1.1.0-h6ef4df4_1
#   mpfr-4.0.1-h3018a27_3
#   mpmath-1.1.0-py27_0
#   multipledispatch-0.6.0-py27_0
#   nltk-3.4-py27_1
#   nose-1.3.7-py27_2
#   numba-0.41.0-py27h6440ff4_0
#   numexpr-2.6.8-py27h7413580_0
#   numpydoc-0.8.0-py27_0
#   odo-0.5.1-py27h992a9f7_0
#   openpyxl-2.5.12-py27_0
#   parso-0.3.1-py27_0
#   path.py-11.5.0-py27_0
#   patsy-0.5.1-py27_0
#   pep8-1.7.1-py27_0
#   ply-3.11-py27_0
#   portaudio-19.6.0-h41429eb_1
#   pyaudio-0.2.11-py27h1de35cc_1
#   pycodestyle-2.4.0-py27_0
#   pycrypto-2.6.1-py27h1de35cc_9
#   pycurl-7.43.0.2-py27ha12b0ac_0
#   pyflakes-2.0.0-py27_0
#   pylint-1.9.2-py27_0
#   pyodbc-4.0.25-py27h0a44026_0
#   pytables-3.4.4-py27h13cba08_0
#   qtawesome-0.5.3-py27_0
#   rope-0.11.0-py27_0
#   scikit-learn-0.20.1-py27h27c97d8_0
#   seaborn-0.9.0-py27_0
#   snappy-1.1.7-he62c110_3
#   snowballstemmer-1.2.1-py27h68ac032_0
#   sortedcollections-1.0.1-py27_0
#   sphinx-1.8.2-py27_0
#   sphinxcontrib-1.0-py27_1
#   sphinxcontrib-websupport-1.1.0-py27_1
#   spyder-3.3.2-py27_0
#   spyder-kernels-0.3.0-py27_0
#   sqlalchemy-1.2.15-py27h1de35cc_0
#   ssl_match_hostname-3.5.0.1-py27_2
#   statsmodels-0.9.0-py27h1d22016_0
#   sympy-1.3-py27_0
#   typing-3.6.6-py27_0
#   unicodecsv-0.14.1-py27h170f95c_0
#   unixodbc-2.3.7-h1de35cc_0
#   werkzeug-0.14.1-py27_0
#   wrapt-1.10.11-py27h1de35cc_2
#   wurlitzer-1.0.2-py27_0
#   xlsxwriter-1.1.2-py27_0
#   xlwings-0.15.1-py27_0
#   xlwt-1.2.0-py27hbeec4ae_0
#
# The following packages will be UPDATED:
#
#   anaconda-navigator                           1.9.6-py27_0 --> 1.9.7-py27_0
#   atomicwrites                                 1.2.1-py27_0 --> 1.3.0-py27_1
#   attrs                               18.2.0-py27h28b3542_0 --> 19.1.0-py27_1
#   backports          pkgs/main/osx-64::backports-1.0-py27_1 --> pkgs/main/noarch::backports-1.0-py_2
#   backports.functoo~ pkgs/main/osx-64::backports.functools~ --> pkgs/main/noarch::backports.functools_lru_cache-1.5-py_2
#   beautifulsoup4                               4.6.3-py27_0 --> 4.7.1-py27_1
#   bleach                                       3.0.2-py27_0 --> 3.1.0-py27_0
#   bokeh                                        1.0.2-py27_0 --> 1.3.1-py27_0
#   bzip2                                    1.0.6-h1de35cc_5 --> 1.0.8-h1de35cc_0
#   cffi                                1.11.5-py27h6174b99_1 --> 1.12.3-py27hb5b8e2f_0
#   chardet                                      3.0.4-py27_1 --> 3.0.4-py27_1003
#   cloudpickle        pkgs/main/osx-64::cloudpickle-0.6.1-p~ --> pkgs/main/noarch::cloudpickle-1.2.1-py_0
#   conda-build                                 3.17.6-py27_0 --> 3.18.9-py27_0
#   conda-verify       pkgs/main/osx-64::conda-verify-3.1.1-~ --> pkgs/main/noarch::conda-verify-3.4.2-py_1
#   configparser                         3.5.0-py27hc7edf1b_0 --> 3.7.4-py27_0
#   cryptography                         2.4.2-py27ha12b0ac_0 --> 2.7-py27ha12b0ac_0
#   cytoolz                            0.9.0.1-py27h1de35cc_1 --> 0.10.0-py27h1de35cc_0
#   dask                  pkgs/main/osx-64::dask-1.0.0-py27_0 --> pkgs/main/noarch::dask-1.2.2-py_0
#   dask-core          pkgs/main/osx-64::dask-core-1.0.0-py2~ --> pkgs/main/noarch::dask-core-1.2.2-py_0
#   dbus                                    1.13.2-h760590f_1 --> 1.13.6-h90a0687_0
#   decorator                                    4.3.0-py27_0 --> 4.4.0-py27_1
#   defusedxml         pkgs/main/osx-64::defusedxml-0.5.0-py~ --> pkgs/main/noarch::defusedxml-0.6.0-py_0
#   dill                                         0.2.9-py27_0 --> 0.3.0-py27_0
#   distributed                                 1.25.1-py27_0 --> 1.28.1-py27_0
#   entrypoints                                  0.2.3-py27_2 --> 0.3-py27_0
#   filelock           pkgs/main/osx-64::filelock-3.0.10-py2~ --> pkgs/main/noarch::filelock-3.0.12-py_0
#   futures                                      3.2.0-py27_0 --> 3.3.0-py27_0
#   glob2                  pkgs/main/osx-64::glob2-0.6-py27_1 --> pkgs/main/noarch::glob2-0.7-py_0
#   glue-core                                   0.14.1-py27_0 --> 0.14.2-py27_0
#   h5py                                 2.8.0-py27h878fce3_3 --> 2.9.0-py27h3134771_0
#   hdf5                                    1.10.2-hfa1e0ec_1 --> 1.10.4-hfa1e0ec_0
#   imageio                                      2.4.1-py27_0 --> 2.5.0-py27_0
#   importlib_metadata                             0.6-py27_0 --> 0.17-py27_1
#   intel-openmp                                   2019.1-144 --> 2019.4-233
#   jinja2                                        2.10-py27_0 --> 2.10.1-py27_0
#   jsonschema                           2.6.0-py27hd9b497e_0 --> 3.0.1-py27_0
#   jupyter_client     pkgs/main/osx-64::jupyter_client-5.2.~ --> pkgs/main/noarch::jupyter_client-5.3.1-py_0
#   jupyter_core       pkgs/main/osx-64::jupyter_core-4.4.0-~ --> pkgs/main/noarch::jupyter_core-4.5.0-py_0
#   kiwisolver                           1.0.1-py27h0a44026_0 --> 1.1.0-py27h0a44026_0
#   libedit                           3.1.20170329-hb402a30_2 --> 3.1.20181209-hb402a30_0
#   liblief                                  0.9.0-h2a1bed3_0 --> 0.9.0-h2a1bed3_2
#   libpng                                  1.6.35-ha441bb4_0 --> 1.6.37-ha441bb4_0
#   libtiff                                  4.0.9-hcb84e12_2 --> 4.0.10-hcb84e12_2
#   libxml2                                  2.9.8-hab757c2_1 --> 2.9.9-hf6e021a_1
#   markupsafe                           1.1.0-py27h1de35cc_0 --> 1.1.1-py27h1de35cc_0
#   mkl                                            2019.1-144 --> 2019.4-233
#   mkl_fft                              1.0.6-py27h27c97d8_0 --> 1.0.12-py27h5e564d8_0
#   more-itertools                               4.3.0-py27_0 --> 5.0.0-py27_0
#   mpl-scatter-densi~                               0.5-py_0 --> 0.6-py_0
#   msgpack-python                       0.5.6-py27h04f5b5a_1 --> 0.6.1-py27h04f5b5a_1
#   nbconvert          pkgs/main/osx-64::nbconvert-5.4.0-py2~ --> pkgs/main/noarch::nbconvert-5.5.0-py_0
#   numpy                               1.15.4-py27hacdab7b_0 --> 1.16.4-py27hacdab7b_0
#   numpy-base                          1.15.4-py27h6575580_0 --> 1.16.4-py27h6575580_0
#   openssl            conda-forge::openssl-1.1.1c-h01d97ff_0 --> pkgs/main::openssl-1.1.1c-h1de35cc_1
#   packaging                                     18.0-py27_0 --> 19.0-py27_0
#   pandas                              0.23.4-py27h6440ff4_0 --> 0.24.2-py27h0a44026_0
#   pandoc                                1.19.2.1-ha5e8f32_1 --> 2.2.3.2-0
#   partd                pkgs/main/osx-64::partd-0.3.9-py27_0 --> pkgs/main/noarch::partd-1.0.0-py_0
#   pathlib2                                     2.3.3-py27_0 --> 2.3.4-py27_0
#   pcre                                      8.42-h378b8a2_0 --> 8.43-h0a44026_0
#   pexpect                                      4.6.0-py27_0 --> 4.7.0-py27_0
#   pillow                               5.3.0-py27hb68e598_0 --> 6.1.0-py27hb68e598_0
#   pip                                           18.1-py27_0 --> 19.1.1-py27_0
#   pkginfo                                      1.4.2-py27_1 --> 1.5.0.1-py27_0
#   plotly                                         3.7.0-py_0 --> 4.0.0-py_0
#   pluggy              pkgs/main/osx-64::pluggy-0.8.0-py27_0 --> pkgs/main/noarch::pluggy-0.12.0-py_0
#   prometheus_client  pkgs/main/osx-64::prometheus_client-0~ --> pkgs/main/noarch::prometheus_client-0.7.1-py_0
#   psutil                               5.4.8-py27h1de35cc_0 --> 5.6.3-py27h1de35cc_0
#   py                                           1.7.0-py27_0 --> 1.8.0-py27_0
#   py-lief                              0.9.0-py27hd4eaf27_0 --> 0.9.0-py27h1413db1_2
#   pygments           pkgs/main/osx-64::pygments-2.3.1-py27~ --> pkgs/main/noarch::pygments-2.4.2-py_0
#   pyopenssl                                   18.0.0-py27_0 --> 19.0.0-py27_0
#   pyparsing          pkgs/main/osx-64::pyparsing-2.3.0-py2~ --> pkgs/main/noarch::pyparsing-2.4.0-py_0
#   pysocks                                      1.6.8-py27_0 --> 1.7.0-py27_0
#   pytest                                       4.0.2-py27_0 --> 4.6.2-py27_0
#   python                                  2.7.15-h8f8e585_6 --> 2.7.16-h97142e2_0
#   python-dateutil                              2.7.5-py27_0 --> 2.8.0-py27_0
#   python-libarchive~                             2.8-py27_6 --> 2.8-py27_11
#   pytz                 pkgs/main/osx-64::pytz-2018.7-py27_0 --> pkgs/main/noarch::pytz-2019.1-py_0
#   pywavelets                           1.0.1-py27h1d22016_0 --> 1.0.3-py27h1d22016_1
#   pyyaml                                3.13-py27h1de35cc_0 --> 5.1.1-py27h1de35cc_0
#   pyzmq                               17.1.2-py27h1de35cc_0 --> 18.0.0-py27h0a44026_0
#   qtconsole          pkgs/main/osx-64::qtconsole-4.4.3-py2~ --> pkgs/main/noarch::qtconsole-4.5.2-py_0
#   qtpy                  pkgs/main/osx-64::qtpy-1.5.2-py27_0 --> pkgs/main/noarch::qtpy-1.8.0-py_0
#   requests                                    2.21.0-py27_0 --> 2.22.0-py27_0
#   scandir                              1.9.0-py27h1de35cc_0 --> 1.10.0-py27h1de35cc_0
#   scikit-image                        0.14.1-py27h0a44026_0 --> 0.14.2-py27h0a44026_0
#   scipy                                1.1.0-py27h1410ff5_2 --> 1.2.1-py27h1410ff5_0
#   setuptools                                  40.6.3-py27_0 --> 41.0.1-py27_0
#   sqlite                                  3.26.0-ha441bb4_0 --> 3.29.0-ha441bb4_0
#   subprocess32                         3.5.3-py27h1de35cc_0 --> 3.5.4-py27h1de35cc_0
#   tblib              pkgs/main/osx-64::tblib-1.3.2-py27ha6~ --> pkgs/main/noarch::tblib-1.4.0-py_0
#   terminado                                    0.8.1-py27_1 --> 0.8.2-py27_0
#   toolz                pkgs/main/osx-64::toolz-0.9.0-py27_0 --> pkgs/main/noarch::toolz-0.10.0-py_0
#   tqdm               pkgs/main/osx-64::tqdm-4.28.1-py27h28~ --> pkgs/main/noarch::tqdm-4.32.1-py_0
#   urllib3                                     1.24.1-py27_0 --> 1.24.2-py27_0
#   wheel                                       0.32.3-py27_0 --> 0.33.4-py27_0
#   zeromq                                   4.2.5-h0a44026_1 --> 4.3.1-h0a44026_3
#   zict                  pkgs/main/osx-64::zict-0.1.3-py27_0 --> pkgs/main/noarch::zict-1.0.0-py_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2019.6.1~ --> pkgs/main::ca-certificates-2019.5.15-0
#   certifi                                       conda-forge --> pkgs/main
#   conda                                         conda-forge --> pkgs/main
#
#
#
# Downloading and Extracting Packages
# qtpy-1.8.0           | 38 KB     | ##################################### | 100%
# imageio-2.5.0        | 3.4 MB    | ##################################### | 100%
# sqlite-3.29.0        | 2.4 MB    | ##################################### | 100%
# h5py-2.9.0           | 928 KB    | ##################################### | 100%
# pandas-0.24.2        | 10.0 MB   | ##################################### | 100%
# cffi-1.12.3          | 210 KB    | ##################################### | 100%
# conda-build-3.18.9   | 531 KB    | ##################################### | 100%
# pcre-8.43            | 227 KB    | ##################################### | 100%
# cryptography-2.7     | 576 KB    | ##################################### | 100%
# conda-4.7.10         | 3.0 MB    | ##################################### | 100%
# importlib_metadata-0 | 39 KB     | ##################################### | 100%
# chardet-3.0.4        | 184 KB    | ##################################### | 100%
# urllib3-1.24.2       | 151 KB    | ##################################### | 100%
# backports-1.0        | 139 KB    | ##################################### | 100%
# soupsieve-1.9.2      | 60 KB     | ##################################### | 100%
# numpy-1.16.4         | 49 KB     | ##################################### | 100%
# libtiff-4.0.10       | 524 KB    | ##################################### | 100%
# msgpack-python-0.6.1 | 85 KB     | ##################################### | 100%
# backports.weakref-1. | 7 KB      | ##################################### | 100%
# dbus-1.13.6          | 560 KB    | ##################################### | 100%
# futures-3.3.0        | 28 KB     | ##################################### | 100%
# pyopenssl-19.0.0     | 79 KB     | ##################################### | 100%
# partd-1.0.0          | 19 KB     | ##################################### | 100%
# mkl_fft-1.0.12       | 154 KB    | ##################################### | 100%
# scikit-image-0.14.2  | 23.2 MB   | ##################################### | 100%
# pexpect-4.7.0        | 79 KB     | ##################################### | 100%
# packaging-19.0       | 37 KB     | ##################################### | 100%
# qtconsole-4.5.2      | 92 KB     | ##################################### | 100%
# dill-0.3.0           | 115 KB    | ##################################### | 100%
# prometheus_client-0. | 42 KB     | ##################################### | 100%
# glob2-0.7            | 14 KB     | ##################################### | 100%
# zipp-0.5.2           | 8 KB      | ##################################### | 100%
# tqdm-4.32.1          | 48 KB     | ##################################### | 100%
# pip-19.1.1           | 1.8 MB    | ##################################### | 100%
# dask-1.2.2           | 11 KB     | ##################################### | 100%
# requests-2.22.0      | 88 KB     | ##################################### | 100%
# dask-core-1.2.2      | 539 KB    | ##################################### | 100%
# py-lief-0.9.0        | 1.5 MB    | ##################################### | 100%
# psutil-5.6.3         | 328 KB    | ##################################### | 100%
# wheel-0.33.4         | 39 KB     | ##################################### | 100%
# hdf5-1.10.4          | 4.5 MB    | ##################################### | 100%
# pywavelets-1.0.3     | 4.3 MB    | ##################################### | 100%
# pytest-4.6.2         | 358 KB    | ##################################### | 100%
# pyrsistent-0.14.11   | 86 KB     | ##################################### | 100%
# bleach-3.1.0         | 228 KB    | ##################################### | 100%
# tblib-1.4.0          | 14 KB     | ##################################### | 100%
# jsonschema-3.0.1     | 86 KB     | ##################################### | 100%
# pysocks-1.7.0        | 29 KB     | ##################################### | 100%
# pkginfo-1.5.0.1      | 41 KB     | ##################################### | 100%
# pillow-6.1.0         | 598 KB    | ##################################### | 100%
# intel-openmp-2019.4  | 1.1 MB    | ##################################### | 100%
# py-1.8.0             | 137 KB    | ##################################### | 100%
# kiwisolver-1.1.0     | 61 KB     | ##################################### | 100%
# atomicwrites-1.3.0   | 12 KB     | ##################################### | 100%
# distributed-1.28.1   | 858 KB    | ##################################### | 100%
# beautifulsoup4-4.7.1 | 139 KB    | ##################################### | 100%
# liblief-0.9.0        | 4.0 MB    | ##################################### | 100%
# more-itertools-5.0.0 | 86 KB     | ##################################### | 100%
# plotly-4.0.0         | 3.8 MB    | ##################################### | 100%
# entrypoints-0.3      | 11 KB     | ##################################### | 100%
# pyparsing-2.4.0      | 58 KB     | ##################################### | 100%
# backports.tempfile-1 | 12 KB     | ##################################### | 100%
# jinja2-2.10.1        | 181 KB    | ##################################### | 100%
# glue-core-0.14.2     | 1.4 MB    | ##################################### | 100%
# setuptools-41.0.1    | 627 KB    | ##################################### | 100%
# configparser-3.7.4   | 41 KB     | ##################################### | 100%
# zict-1.0.0           | 12 KB     | ##################################### | 100%
# filelock-3.0.12      | 12 KB     | ##################################### | 100%
# bzip2-1.0.8          | 104 KB    | ##################################### | 100%
# conda-verify-3.4.2   | 25 KB     | ##################################### | 100%
# libxml2-2.9.9        | 1.9 MB    | ##################################### | 100%
# subprocess32-3.5.4   | 47 KB     | ##################################### | 100%
# terminado-0.8.2      | 21 KB     | ##################################### | 100%
# libpng-1.6.37        | 325 KB    | ##################################### | 100%
# toolz-0.10.0         | 50 KB     | ##################################### | 100%
# mkl-2019.4           | 155.2 MB  | ##################################### | 100%
# markupsafe-1.1.1     | 27 KB     | ##################################### | 100%
# pygments-2.4.2       | 664 KB    | ##################################### | 100%
# certifi-2019.6.16    | 155 KB    | ##################################### | 100%
# jupyter_core-4.5.0   | 48 KB     | ##################################### | 100%
# defusedxml-0.6.0     | 23 KB     | ##################################### | 100%
# pyyaml-5.1.1         | 166 KB    | ##################################### | 100%
# scipy-1.2.1          | 15.7 MB   | ##################################### | 100%
# pluggy-0.12.0        | 20 KB     | ##################################### | 100%
# backports.functools_ | 9 KB      | ##################################### | 100%
# mpl-scatter-density- | 647 KB    | ##################################### | 100%
# attrs-19.1.0         | 56 KB     | ##################################### | 100%
# cytoolz-0.10.0       | 363 KB    | ##################################### | 100%
# nbconvert-5.5.0      | 381 KB    | ##################################### | 100%
# anaconda-navigator-1 | 4.8 MB    | ##################################### | 100%
# jupyter_client-5.3.1 | 69 KB     | ##################################### | 100%
# numpy-base-1.16.4    | 4.2 MB    | ##################################### | 100%
# bokeh-1.3.1          | 4.0 MB    | ##################################### | 100%
# pandoc-2.2.3.2       | 13.8 MB   | ##################################### | 100%
# pytz-2019.1          | 236 KB    | ##################################### | 100%
# pathlib2-2.3.4       | 35 KB     | ##################################### | 100%
# python-libarchive-c- | 22 KB     | ##################################### | 100%
# cloudpickle-1.2.1    | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
# Collecting tensorflow==2.0.0-beta1
#   Downloading https://files.pythonhosted.org/packages/cd/4f/fd36ed6f439cd9dc272ab24d125d301bf2ae4b47649b6a354f31fffba4e8/tensorflow-2.0.0b1-cp27-cp27m-macosx_10_11_x86_64.whl (87.9MB)
#      |████████████████████████████████| 87.9MB 24.0MB/s eta 0:00:01
# Collecting grpcio>=1.8.6 (from tensorflow==2.0.0-beta1)
#   Using cached https://files.pythonhosted.org/packages/2a/ef/f713328b4ce158e76b9fd7b4b440a5b7cc5744a6f61a1eba27a6ccbc1932/grpcio-1.22.0-cp27-cp27m-macosx_10_9_x86_64.whl
# Collecting keras-applications>=1.0.6 (from tensorflow==2.0.0-beta1)
# Collecting mock>=2.0.0 (from tensorflow==2.0.0-beta1)
#   Using cached https://files.pythonhosted.org/packages/05/d2/f94e68be6b17f46d2c353564da56e6fb89ef09faeeff3313a046cb810ca9/mock-3.0.5-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: backports.weakref>=1.0rc1 in /anaconda2/lib/python2.7/site-packages (from tensorflow==2.0.0-beta1) (1.0.post1)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /anaconda2/lib/python2.7/site-packages (from tensorflow==2.0.0-beta1) (1.1.0)
# Collecting google-pasta>=0.1.6 (from tensorflow==2.0.0-beta1)
#   Using cached https://files.pythonhosted.org/packages/35/95/d41cd87d147742ef72d5d1dc317318486e3fbffdadf24a60e70dedf01d56/google_pasta-0.1.7-py2-none-any.whl
# Requirement already satisfied, skipping upgrade: wheel in /anaconda2/lib/python2.7/site-packages (from tensorflow==2.0.0-beta1) (0.33.4)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /anaconda2/lib/python2.7/site-packages (from tensorflow==2.0.0-beta1) (0.7.1)
# Collecting tb-nightly<1.14.0a20190604,>=1.14.0a20190603 (from tensorflow==2.0.0-beta1)
#   Using cached https://files.pythonhosted.org/packages/c3/df/f15af3319c0094c0c74ca291f10d7b1235196988ab67c11bc09950bb7b07/tb_nightly-1.14.0a20190603-py2-none-any.whl
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /anaconda2/lib/python2.7/site-packages (from tensorflow==2.0.0-beta1) (1.12.0)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.14.5 in /anaconda2/lib/python2.7/site-packages (from tensorflow==2.0.0-beta1) (1.16.4)
# Collecting tf-estimator-nightly<1.14.0.dev2019060502,>=1.14.0.dev2019060501 (from tensorflow==2.0.0-beta1)
#   Using cached https://files.pythonhosted.org/packages/32/dd/99c47dd007dcf10d63fd895611b063732646f23059c618a373e85019eb0e/tf_estimator_nightly-1.14.0.dev2019060501-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: enum34>=1.1.6 in /anaconda2/lib/python2.7/site-packages (from tensorflow==2.0.0-beta1) (1.1.6)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /anaconda2/lib/python2.7/site-packages (from tensorflow==2.0.0-beta1) (3.9.0)
# Collecting wrapt>=1.11.1 (from tensorflow==2.0.0-beta1)
# Requirement already satisfied, skipping upgrade: gast>=0.2.0 in /anaconda2/lib/python2.7/site-packages (from tensorflow==2.0.0-beta1) (0.2.2)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /anaconda2/lib/python2.7/site-packages (from tensorflow==2.0.0-beta1) (1.1.0)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /anaconda2/lib/python2.7/site-packages (from tensorflow==2.0.0-beta1) (0.8.0)
# Requirement already satisfied, skipping upgrade: futures>=2.2.0; python_version < "3.2" in /anaconda2/lib/python2.7/site-packages (from grpcio>=1.8.6->tensorflow==2.0.0-beta1) (3.3.0)
# Requirement already satisfied, skipping upgrade: h5py in /anaconda2/lib/python2.7/site-packages (from keras-applications>=1.0.6->tensorflow==2.0.0-beta1) (2.9.0)
# Requirement already satisfied, skipping upgrade: funcsigs>=1; python_version < "3.3" in /anaconda2/lib/python2.7/site-packages (from mock>=2.0.0->tensorflow==2.0.0-beta1) (1.0.2)
# Collecting werkzeug>=0.11.15 (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1)
#   Using cached https://files.pythonhosted.org/packages/d1/ab/d3bed6b92042622d24decc7aadc8877badf18aeca1571045840ad4956d3f/Werkzeug-0.15.5-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /anaconda2/lib/python2.7/site-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (41.0.1)
# Collecting markdown>=2.6.8 (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1)
#   Using cached https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl
# Installing collected packages: grpcio, keras-applications, mock, google-pasta, werkzeug, markdown, tb-nightly, tf-estimator-nightly, wrapt, tensorflow
# Successfully installed google-pasta-0.1.7 grpcio-1.22.0 keras-applications-1.0.8 markdown-3.1.1 mock-3.0.5 tb-nightly-1.14.0a20190603 tensorflow-2.0.0b1 tf-estimator-nightly-1.14.0.dev2019060501 werkzeug-0.15.5 wrapt-1.11.2
# 2.0.0-beta0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-0855b5240959> in <module>
#      12
#      13
# ---> 14 tf.enable_eager_execution()
#
# AttributeError: module 'tensorflow' has no attribute 'enable_eager_execution'

# %%
import tensorflow as tf
print(tf.__version__)

# This is needed for the iterator over the data
# But not necessary if you have TF 2.0 installed
#!pip install tensorflow==2.0.0-beta0


#tf.enable_eager_execution()
# Out:
# 2.0.0-beta0

# %%
import tensorflow_datasets as tfds
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)
# Out:
# W0804 01:03:57.368570 140735902892928 dataset_builder.py:439] Warning: Setting shuffle_files=True because split=TRAIN and shuffle_files=None. This behavior will be deprecated on 2019-08-06, at which point shuffle_files=False will be the default for all splits.

# %%
friends_chars={} 
Rachel=[]
Ross=[]
Joey=[]
Chandler=[]
Phoebe=[]
Monica=[]
with open("transcripts_friends/season1/merged.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        #print("Line {}: {}".format(cnt, line))
        if line.startswith('Rachel:'):
            Rachel.append(line[8:])
        elif line.startswith('Ross:'):
            Ross.append(line[6:])
        elif line.startswith('Monica:'):
            Monica.append(line[8:])
        elif line.startswith('Chandler:'):
            Chandler.append(line[10:])
        if line.startswith('Phoebe:'):
            Phoebe.append(line[8:])
        if line.startswith('Joey:'):
            Joey.append(line[6:])

friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

# %%
import pandas as pd
df6 = pd.DataFrame(friends_chars['MONICA'])
df5 = pd.DataFrame(friends_chars['ROSS'])

df4 = pd.DataFrame(friends_chars['RACHEL'])
df3 = pd.DataFrame(friends_chars['PHOEBE'])

df2 = pd.DataFrame(friends_chars['JOEY'])
df1 = pd.DataFrame(friends_chars['CHANDLER'])

# %%
df1.head()
# Out:
#                                                    0
# 0  All right Joey, be nice.  So does he have a hu...
# 1                        Sounds like a date to me.\n
# 2  Alright, so I'm back in high school, I'm stand...
# 3  Then I look down, and I realize there's a phon...
# 4                                    That's right.\n

# %%
listOfScores1 = ['Chandler'] *df1.shape[0]
listOfScores2 = ['Joey'] *df2.shape[0]
listOfScores3 = ['Phoebe'] *df3.shape[0]
listOfScores4 = ['Rachel'] *df4.shape[0]
listOfScores5 = ['Ross'] *df5.shape[0]
listOfScores6 = ['Monica'] *df6.shape[0]

# %%
df1['Score'] = listOfScores1
df2['Score'] = listOfScores2 
df3['Score'] = listOfScores3
df4['Score'] = listOfScores4
df5['Score'] = listOfScores5
df6['Score'] = listOfScores6

# %%
df1=df1.rename(columns={0: 'dialogue'})
df2=df2.rename(columns={0: 'dialogue'})
df3=df3.rename(columns={0: 'dialogue'})
df4=df4.rename(columns={0: 'dialogue'})
df5=df5.rename(columns={0: 'dialogue'})
df6=df6.rename(columns={0: 'dialogue'})

# %%
df = pd.concat([df1, df2,df3,df4,df5,df6])
df.tail()
# Out:
#                                                dialogue   Score
# 1799  Well, it's the thought. Hey, doesn't Ross's fl...  Monica
# 1800                                         Oh, why?\n  Monica
# 1801  (gets up) No, no, no, no, no, no pressure, no ...  Monica
# 1802  I am not 'so'! OK, I was a teensy bit weird at...  Monica
# 1803  Behind my brother's back? (Rachel glares at he...  Monica

# %%
from io import StringIO
col = ['Score', 'dialogue']
df = df[col]
df = df[pd.notnull(df['dialogue'])]
df.columns = ['Score', 'dialogue']
df['category_id'] = df['Score'].factorize()[0]
category_id_df = df[['Score', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'Score']].values)
df.tail()
# Out:
#        Score                                           dialogue  category_id
# 1799  Monica  Well, it's the thought. Hey, doesn't Ross's fl...            5
# 1800  Monica                                         Oh, why?\n            5
# 1801  Monica  (gets up) No, no, no, no, no, no pressure, no ...            5
# 1802  Monica  I am not 'so'! OK, I was a teensy bit weird at...            5
# 1803  Monica  Behind my brother's back? (Rachel glares at he...            5

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
df.groupby('Score').dialogue.count().plot.bar(ylim=0)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
X_train, X_test, y_train, y_test = train_test_split(df['dialogue'], df['category_id'], random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
y_train.shape
# Out:
# (7278,)

# %%
X_train.shape
# Out:
# (7278,)

# %%
X_test.shape
# Out:
# (2426,)

# %%
import numpy as np

training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

# str(s.tonumpy()) is needed in Python3 instead of just s.numpy()
for s,l in zip(X_train, y_train):
  training_sentences.append(str(s))
  training_labels.append(l)
  
for s,l in zip(X_test, y_test):
  testing_sentences.append(str(s))
  testing_labels.append(l)
  
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %%
y_test.shape
# Out:
# (2426,)

# %%
training_sentences
# Out:
# ["C'mon! Just try to picture her not pregnant, that's all.\n",
#  "Yes! Way to go, man! (Chandler and Ross hug. Something crunches in Ross' shirt pocket.) Still got the egg, huh?\n",
#  'Do they wait for me to do this?\n',
#  "Oh Ross, you're so great. (she playfully rubs his head and gets up)\n",
#  'Uh-oh.\n',
#  'Hey, when did you and Susan meet Huey Lewis?\n',
#  "Um, that's ok! (throws it in fire) Ok. All right. Now we need the semen of a righteous man.\n",
#  'Yes, I know, but her friend sounds like such a...\n',
#  'I swear you said you had the keys.\n',
#  "Yup! You could plunk me down in the middle of any woman's uterus, no compass, and I can find my way out of there like that! (snaps fingers)\n",
#  "Joseph Stalin. I think you'd remember that!\n",
#  'Rach, wait, I can cancel...\n',
#  "Rachel, what's going on? I mean isn't this the same Barry who you left at the altar?\n",
#  "Nice going, imp. OK, it's OK. All I need to do is reach over and put it in my mouth. (Chandler slyly grabs the gum from the wall and slides it back in his mouth.)\n",
#  'Because!\n',
#  'What?\n',
#  'No, we were just laughing. You know, how laughter can be infectious.\n',
#  'Hey.\n',
#  'Yeah.\n',
#  'Well, you should have.\n',
#  'You are just like Jack.\n',
#  'I mean presumably, the biggest part of your job is done.\n',
#  'Okay.\n',
#  "(they shake hands) Hello, Susan. (To Carol) Good shake. Good shake. So, uh, we're just waiting for...?\n",
#  'Does it always, uh--?\n',
#  "(shouting to Chandler) Chandler! He's here!\n",
#  "Yes, yes I did, but what I didn't say was what I was about to say, what I wanted to say was, uh... would you like to go out with me sometime, thankyou, goodnight. (He walks back to the others but she calls him back.)\n",
#  'Relax, I’ll fix it.\n',
#  'So I guess you all saw it.\n',
#  'You know who shaved you? That was me.\n',
#  'At the coffeehouse, right.\n',
#  "Oh, no! I- I can't drink this now!\n",
#  "(exasperated) Yes, Chandler, that's exactly what it is. It's your hair.\n",
#  'Did you ever go out with a guy your friends all really like?\n',
#  "You're a lucky man. You know what I miss the most about her? That cute nibbly noise when she eats. Like a happy little squirrel, or a weasel.\n",
#  'Dad!\n',
#  "No-no-no-no, we're done.\n",
#  'Oh... Milwaukee.\n',
#  'Yeah, yeah, she works over at that place, uh...\n',
#  'Oh, hang on, hang on. Does Aunt Monica get a say in this?\n',
#  'What?! You slept with Jason?\n',
#  'Look, I am totally, totally over her, OK, I just... (Rachel comes over, Ross lays head on table): Hiiii!\n',
#  "You know, they're not actually supposed to have... (Ross looks at her sheepishly) I'll work on the lumps. Joey, you're going home, right?\n",
#  "Don't you realise what you're-you're doing to yourself?\n",
#  'What?\n',
#  'Ohhhh!! (Mindy starts to sob.) ...What? What?\n',
#  "So great! He showed me where the restaurant's going to be. It's this, it's this cute little place on 10th Street. Not too big, not too small. Just right.\n",
#  "All right, I'm nine years old.\n",
#  'Not a good day for birds...\n',
#  "Now she's passed.\n",
#  'See, there you go, the cleansing works!\n',
#  'And then he did.\n',
#  "Please, no, go, that'd be fine!\n",
#  'Wow. Then I would definitely not recommend Mrs. Doubtfire.\n',
#  "I dunno, but.. I think it's about to attack the Enterprise.\n",
#  "Well, well, well, hop back in bucko, cause I got four sixes! (lays down cards) I won! I actually won! Oh my God! Y'know what? (collects chips) I think I'm gonna make a little Ross pile. (holds up a chip) I think that one was Ross's, and I think—oh—that one was Ross's. Yes! (Starts singing): Well, I have got your money, and you'll never see it...\n",
#  '"See you around?"\n',
#  'Can we just start throwing things in?\n',
#  "Hey. How did, uh, how'd it go today?\n",
#  'Oh, listen. If this is about those prank memos, I had nothing to do with them. Really. Nothing at all. Really. (Chandler tries to hide a rubber chicken from the woman.) Nothing.\n',
#  '(Looking out at the balcony) So tell me something, is leaving the Christmas lights up part of your plan to keep us merry all year long?\n',
#  'Do you have a plan?\n',
#  'Well, not... worried, just... wondering.\n',
#  '(quietly) ...spender.\n',
#  "Well, I guess we've established who's staying here with Monica...\n",
#  '(smiling) You betcha!\n',
#  '(sitting) OK.\n',
#  'Yeah\n',
#  "(overemphasizing) Mmmmmm! Everything smells so delicious! You know, I can't remember a time I smelt such a delicious combination of (Monica signals her to stop) of, OK, smells.\n",
#  'That tone will not make me go any faster.\n',
#  "I don't know, but when I spoke to her, she said she had already passed the mucus plug.\n",
#  'What?\n',
#  '...Does the knuckle-cracking bother everybody?\n',
#  "Ok, you weren't there.\n",
#  'Again?\n',
#  "Yeah! Oh, c'mere, Marcel! Oh, Marcel, c'mere!\n",
#  "Ok, um, uh, more clothes in the dryer? (Ross turns and bangs his head on an open dryer door.) I'm fine, I'm fine.\n",
#  'Why? Why would you wanna... do that?  Why?\n',
#  'So what, like people are gonna come in and think, "Uh-oh, I\'m outside again?" Of course!\n',
#  'Jeez, you say one thing, and...\n',
#  "I just can't believe you're in here. I mean, what am I gonna do without you? Who's gonna crash the embassy parties with me? Who's gonna take me to the Big Apple Circus?\n",
#  '(reading): OK... Dear Ms. Green... yeah... yeah... yeah... No. (crumpes up letter)\n',
#  'That tone will not make me go any faster.\n',
#  'Are you gonna go over there?\n',
#  'Hi, is uh, is Carol here?\n',
#  "Okay, is this like 'I have an early class tomorrow' or 'I'm secretly married to a goat?'\n",
#  'You knew about that?\n',
#  '(acts surprised) What? (pause) Why not?\n',
#  "Hey, you.... So, what's up?\n",
#  "Oh, like I wasn't dreading tomorrow enough, having to give it back to him... 'Hi Barry! Remember me? I'm the girl in the veil who stomped on your heart in front of your entire family!' Oh God and now I'm gonna have to return the ring, without the ring, which makes it so much harder...\n",
#  'Based on this play? ...Based on this play!\n',
#  "Well... I'm helping out down at the N.Y.U. Med School with some... research.\n",
#  'No? What happened, big guy?\n',
#  'Hey.\n',
#  'Oh, that is so sweet. (Touched, she puts an arm around her friend and kisses her.) Oh gosh, love you. Insurance?\n',
#  "(flailing arms in protest) Oh, hey hey hey, ho ho ho, hello, guy who doesn't want to know, standing right here!\n",
#  '(singing) Love is sweet as summer showers, love is a wondrous work of art, but your love oh your love, your love...is like a giant pigeon...crapping on my heart.  La-la-la-la-la- (some guy gives her some change and to that guy) Thank you. (sings) La-la-la-la...ohhh!\n',
#  "But I haven't used my card in weeks!\n",
#  'Are there no conscious men in the city for you two?\n',
#  'You cuddled.\n',
#  "I'm fine.\n",
#  'Who?\n',
#  '(pause)...Yeah. Yeah, I do.\n',
#  'Was there...uh, huh, huh, huh... andybody, anybody else there.\n',
#  'Ross.\n',
#  'OK, then get me your purse.\n',
#  'You know, if you tilt your head to the left, and relax your eyes, it kinda looks like an old potato.\n',
#  "I'm sorry, you know, maybe I wasn't being clear. Uh, this is our cart.\n",
#  'Would you excuse me for a second?\n',
#  "I guess you don't.\n",
#  '(singing) Love is sweet as summer showers, love is a wondrous work of art, but your love oh your love, your love...is like a giant pigeon...crapping on my heart.  La-la-la-la-la- (some guy gives her some change and to that guy) Thank you. (sings) La-la-la-la...ohhh!\n',
#  "Ooh! Ooh! And I brought Operation! But, um, I lost the tweezers, so we can't operate. But we can prep the guy!\n",
#  'By all means.\n',
#  'Oh, it is.\n',
#  'I just wish there was something we could do. (Bends down and talks to him) Hello. Hello, Coma Guy. GET UP, YOU GIRL SCOUT! UP! UP! UP!\n',
#  'Well, he made a move on me.\n',
#  "No, no. Uh... no, see, uh, you-you can't do that.\n",
#  "They wanna know if I'm okay. Okay.. they wanna know if I'm okay, okay, let's see. Well, let's see, the FICA guys took all my money, everyone I know is either getting married, or getting promoted, or getting pregnant, and I'm getting coffee! And it's not even for me! So if that sounds like I'm okay, okay, then you can tell them I'm okay, okay?\n",
#  'Ohhhh (Hugs her and sighs)\n',
#  'Did you call the cops?\n',
#  "I don't get it, I mean, you just got him. How can he be an adult already?\n",
#  'Mm.\n',
#  "C'mon, she's your mom!\n",
#  "(pauses) I'm pretty sure that it is...\n",
#  'Done.\n',
#  "Eww, I don't wanna do that.\n",
#  "Who's this from?\n",
#  "I'm still on my first. I just think you're nice.\n",
#  "Hey, hey, hey, that's not the rule and you know it.\n",
#  "Phoebe, you're gonna be with your grandma?\n",
#  'I know.\n',
#  '(hesitates) Are you sure?\n',
#  "Exactly. Weekend At Bernie's! Dead guy getting hit in the groin twenty, thirty times! No?\n",
#  "I don't know! Why don't you just explain? What do they want? Find out what they want!\n",
#  'Alright, check.\n',
#  'Ok, have a good break-up.\n',
#  'Ahhhh!\n',
#  '(as Monica) Hi, remember us?\n',
#  "(on phone) Hello?(Listens) Mindy! Hi! Hey, how are you? (Listens) Yes, yes, I've heard, congratulations, that is so great. (Listens) Really? (Listens) Oh. (Listens) Okay. Okay, well I'm working tomorrow, but if you want you can, you can, you can come by and... (Listens) Okay... (Listens) Great... (Listens) Great... (Listens) All right, so I'll, so I'll see you tomorrow! (Listens) Okay.. (Listens) Okay... (Listens) Bye. (Hangs up and sits down heavily.) Oh God. Oh God. Oh God.\n",
#  "What's goin' on?\n",
#  "I-I'm, I'm having a boy?\n",
#  'Which what?\n',
#  'You think?\n',
#  "Hello? Oh, uh, Rachel, it's the Visa card people.\n",
#  'OK.\n',
#  "Okay, alright, you buy me a soda, and then we're even. Okay?\n",
#  'Hey!\n',
#  'Oh, I cursed it. So now bad things will happen to he who spends it.\n',
#  'Hey, Janice.\n',
#  'The Luisa from home room!\n',
#  "Look, I don't even know how I feel about him yet. Just give me a chance to figure that out.\n",
#  'Oh, have either one of you guys ever been to the Rainbow Room? Is it real expensive?\n',
#  'Anyway, um, (Gets the ring out of her purse.) I guess this belongs to you. And thank you for giving it to me.\n',
#  "Ethan, it's um... it's icky.\n",
#  'What?\n',
#  'Whose little ball of paper is this?!\n',
#  "Oh! Man, I never thought I'd be here.. (She leans back onto his hand.)\n",
#  "(looking) Nono, that would be me again. I'm, uh, just trying something.\n",
#  'Marcel?!\n',
#  'Marcel! Where are you going with that disc?\n',
#  "Really? He does? (taking the phone) Hey, buddy, what's up! Oh, she told you about that, huh. Well, yeah, I have one now and then. Well, yeah, now. Well, it's not that big- ..well, that's true,.. Gee, y'know, no-one- no-one's ever put it like that before. Well, okay, thanks! (He hands the phone back and stubs out his cigarette.)\n",
#  "I'd just like to say that I'm totally behind this experiment. In fact, I'd very much like to butter your head.\n",
#  'Phoebe, what is it?\n',
#  "Big Bird's friend.\n",
#  'Alright, now try taking a puff.\n',
#  "Oh! Man, I never thought I'd be here.. (She leans back onto his hand.)\n",
#  "Look, you'll get there. You're an amazing chef.\n",
#  '...What did I ask?\n',
#  'Then she came back with "The question is, when are you gonna grow up and realise I have a bomb?"\n',
#  "No, I know. That's a part of the whole, you know, them-not-liking-you-extravaganza.\n",
#  "Ooh, oh, I've gotta go. (raises) Whoa, oh, head rush. One more, and then I have to go. (sits down, and then raises again) Cool!\n",
#  'Ah!\n',
#  'Are you okay?\n',
#  "(entering) Hey, you know our phone's not working?\n",
#  'Come here. (he hugs Rachel) Listen, you deserve so much better than him...you know, I mean, you, you, you should be with a guy who knows what he has when he has you.\n',
#  "All right, c'mere, gimme your feet. (She starts massaging them.)\n",
#  "All right, well, you're right, these are the best oatmeal cookies I've ever had.\n",
#  "Thanks, Phoebe. But I just don't really see myself in a big white hat.\n",
#  "(brings a plate of tiny appetizers over) Here you go, maybe this'll cheer you up.\n",
#  'I know.\n',
#  '(to Steve) This is Rachel.\n',
#  "(chuckles nervously) The sex? (chuckles) Um, I'm having enough trouble with the image of you and Susan together, when you throw in Tanya (miming washing hair, that's the best I could think of), yaw...\n",
#  "Yeah. Thought I'd give it a shot. I'm still on the first chapter. Now, do you think his 'love stick can be liberated from its denim prison'?\n",
#  "Man, hell of a two weeks, huh? Y'know what, though? I really feel like I learned something.\n",
#  'Yeah, yeah.\n',
#  "Well, 'cause then they'd be like my mom used to make them, you know, before she died.\n",
#  "That's nice. Get out Let's go, come on.\n",
#  "Hey, that woman's got an ass like Carol's! (They turn to stare at him.) What? Thought we were trying to find stuff.\n",
#  'What the hell are you doing? You scared the crap outta me.\n',
#  'Hello.\n',
#  "Marcel, I'm hungry.\n",
#  'Yeah.\n',
#  'See your twenty-five...and...uh, Monica, get my purse.\n',
#  'Thanks.\n',
#  '(grabs the bill) Give me that!\n',
#  "C'mon, you're going out with the guy! There's gotta be something wrong with him!\n",
#  "You- uh- y'know what, I'm gonna go. I don't- I don't think I can be involved in this particular thing right now.\n",
#  'That was not an incident! I-I was gesturing, a-and the plate slipped out of my hand.\n',
#  'Err, right.\n',
#  "Oh, just, y'know.... science.\n",
#  'Yeah, listen. Okay, before you do anything Joey-like, you might wanna run it by err... (he indicates Phoebe, who is helping Ross understand the remote control.)\n',
#  "No, I'm fine.\n",
#  'Hey.\n',
#  "And I hope Barry doesn't kill you and eat you in Aruba.\n",
#  '(as Ursula) If it was, would you stop hanging out with her?\n',
#  "I can't believe it. Paolo kissed my mom?\n",
#  '(out loud): We have apple cinnamon...\n',
#  'And everybody knows this?\n',
#  'So, um, did she...\n',
#  'Oh...\n',
#  'Is there? Is there someone else?\n',
#  "Oh, God, he's such a pig,\n",
#  'Hi, Paul, is it?\n',
#  "Where the hell've you been?\n",
#  'No.\n',
#  "What future boyfriends? Nono, I th- I think this could be, y'know, it.\n",
#  'Good for you. (jumps suddenly) Uh, quarters or rolls of quarters?\n',
#  'Yeah.\n',
#  'And I assume, Chandler, you are still boycotting all the pilgrim holidays.\n',
#  "Why not? Come on! Just, just close your eyes and tell me what you'd like to be doing right now.\n",
#  "I don't know. It's just not the same without Mom in the kitchen.\n",
#  'Oh, poor little Tooty is scared to death. We should find his owner.\n',
#  '(angry) Joey!\n',
#  'Nothing, just your overcoat sounds remarkably like Brent Mussberger.\n',
#  '(holding a card and waving it in front of her face) Hey you guys, look, the one-eyed jack follows me wherever I go. (they look at her) Right, OK, serious poker.\n',
#  "Marsha, these are cave people. Okay? They have issues like 'Gee, that glacier's getting kinda close.' See?\n",
#  'What? (the cat jumps on his shoulders) Ow!\n',
#  "No way! Mr.Salty is a sailor, all right, he's got to be, like, thetoughest snack there is.\n",
#  "What are you talking about? 'One woman'? That's like saying there's only one flavor of ice cream for you. Lemme tell you something, Ross. There's lots of flavors out there. There's Rocky Road, and Cookie Dough, and Bing! Cherry Vanilla. You could get 'em with Jimmies, or nuts, or whipped cream! This is the best thing that ever happened to you! You got married, you were, like, what, eight? Welcome back to the world! Grab a spoon!\n",
#  "(looking) Nono, that would be me again. I'm, uh, just trying something.\n",
#  'Me too.\n',
#  'Really?\n',
#  'Off to see young Ethan?\n',
#  "Hey, we all had better plans. This was nobody's first choice.\n",
#  'Outside.\n',
#  '(on phone) Daddy... Daddy... Daddy, why whyyy would I sleep with Billy Dreskin? His father tried to put you out of business! (Rachel turns to Monica, clasping the receiver to her bosom so Dr.Green can\'t hear, while mouthing "You are...") ...dead!\n',
#  "So Rachel, what're you, uh... what're you up to tonight?\n",
#  "No, no, no... why, because it might get weird for everyone else? Who cares about them. This is about us. Look, I-I've been in love with you since, like, the ninth grade.\n",
#  'Ooh, you guys have to make a wish.\n',
#  'Yeah, she said you looked like Ingrid Bergman that day.\n',
#  'Alright... (shuffles cards expertly, all the guys stare in amazement)\n',
#  "Why? Because everything is my responsibility? Isn't it enough that I'm making Thanksgiving dinner for everyone? You know, everyone wants a different kind of potatoes, so I'm making different kinds of potatoes. Does anybody care what kind of potatoes I want? Nooooo, no, no! (starting to cry) Just as long as Phoebe gets her peas and onions, and Mario gets his tots, and it's my first Thanksgiving, and it's all burned, and, and I... I...\n",
#  '(sarcastic) Oh. That WENUS.\n',
#  'Is he not cute enough for you?\n',
#  "(to Rachel) What's the matter? Why so scrunchy?\n",
#  "No!! Okay?! Why does everyone keep fixating on that? She didn't know, how should I know?\n",
#  'What, Ethan? He got to spend the whole day with you!\n',
#  "Come on. These people'll scooch down. You guys'll scooch, won't you? Let's try scooching! Come on. Come on. Uh, Kristen Riggs, this is Carol Willick. Carol, Kristin. Uh, Carol teaches sixth grade. And, Kristin, Kristin...(struggling)...does something that, funnily enough, wasn't even her major!\n",
#  "Ok, Monica, only dogs can hear you now, so, look, the door's open. Here we go.\n",
#  'Yeah, see.. you took mine. Chandler, what about you?\n',
#  "Well, it's like, last night, I couldn't do the thing that usually makes me great. So I had to do all this other stuff. And the response I got... man, oh man, it was like a ticker tape parade!\n",
#  'Every day is Lesbian Lover Day.\n',
#  'What?\n',
#  'Alright, Cincinnati, no blinds, everybody ante. (deals cards)\n',
#  'What?!\n',
#  'I thought that was just a rumour.\n',
#  "I don't know. I don't know... I thought about it all the way there, and I thought about it all the way back... and, uh, oh, you guys, y'know, it's Ross. Y'know what I mean? I mean, it's Ross.\n",
#  'Ross!\n',
#  '-leg?\n',
#  'Remember when we went to Central Park and rented boats?.. That was fun.\n',
#  "...Well, y'know, part of me wants that, but it's like I'm two guys, y'know? I mean, one guy's going 'Shut up! This is great!' But there's this other guy. Actually it's the same guy that wells up every time that Grinch's heart grows three sizes and breaks that measuring device... And he's saying, y'know, 'This is too hard! Get out! Get out!'\n",
#  'Oh my God..\n',
#  'Yeah, save it for the cab, okay.\n',
#  'Look at you! How, how do you feel?\n',
#  "Can't do it, can you?\n",
#  "(pulls his hand away) Okay! Okay. (To his parents) Look, I, uh- I realise you guys have been wondering what exactly happened between Carol and me, and, so, well, here's the deal. Carol's a lesbian. She's living with a woman named Susan. She's pregnant with my child, and she and Susan are going to raise the baby.\n",
#  "The hell with hockey, let's all do that!\n",
#  'Remembered what?\n',
#  'Myyy mother, ladies and gentlemen.\n',
#  "'Tonight' tonight?\n",
#  "Ben, Ben, hey Ben. Nothing. I don't think that's his name.\n",
#  'We have got to start locking that door!\n',
#  '(pointing at the drawing, upset) Bye... bye... BIRDIE.\n',
#  'OK. (Ross goes out on the balcony to talk to Rachel)\n',
#  'Oh my god, oh, you guys are great.\n',
#  "Yeah, well, you wouldn't think it was cool if you're eleven years old and all your friends are passing around page 79 of 'Mistress Bitch.'\n",
#  "(entering) How's it going?\n",
#  'No, nothing like that. I was just...such a dummie. I taught this "massage-yourself-at-home-workshop." And they are.\n',
#  'Saw what?\n',
#  'Yes, yes!\n',
#  'Huh.\n',
#  "Some days it's all I can think about.\n",
#  "(To Ross) I can't believe this! What the hell were you thinking?\n",
#  "It's great. Maybe tomorrow we can rent a car and run over some puppies.\n",
#  'Alright, Cincinnati, no blinds, everybody ante. (deals cards)\n',
#  '(leaving to serve others) Good for me!\n',
#  'Well, no, although I did have an imaginary friend, who... my parents actually preferred.\n',
#  'Because!\n',
#  "Okay, okay, what's going on?\n",
#  'Good for you, Joey.\n',
#  "Yeah, I mean... I think when it's your shot, y'know, you-you know it's your shot. Did it... feel like your shot..?\n",
#  'Alright, whadyou do with him?\n',
#  'Oh, how’d she take it?\n',
#  'Ooh! Bath salts would be nice.\n',
#  "(upset) Oh my Goood! Oh, do you think it's on all of them?\n",
#  '(to Ross): I thought we had them!\n',
#  'OK... see your two... and I raise you twenty. (throws it in)\n',
#  'Okay.\n',
#  "Oh, that's nice!\n",
#  "Okay. (They split it.) You know you probably didn't know this, but back in high school, I had a, um, major crush on you.\n",
#  'Yes, and I get my ya-yas from Ikea. You have to put them together yourself, but they cost a little less.\n',
#  'Yes have you seen any?\n',
#  'What, Phoebe, did you whip the potatoes? Ross needs lumps!\n',
#  'Oh, come on. What was with that whole Black Bart speech? (mimicking): "When I play poker, I\'m not a nice guy!"\n',
#  "During a blackout? He'd get trampled!\n",
#  "C'mon! C'mon!\n",
#  "Or, or, y'know, um, 'I think we should see other people' means 'Ha, ha, I already am'.\n",
#  "(Hushes her) Alright, great. Thanks a lot. (Hangs up) I'm going to tap class.\n",
#  "You know, I don't get this. A month ago, these people were my friends. You know, just because I'm in charge doesn't mean I'm a different person.\n",
#  'We checked. A lot.\n',
#  '(panicked) The oven is on.\n',
#  "Oh, well... 'cause.... you just... I don't like this question.\n",
#  'Good luck, man. I hope you get it.\n',
#  'Check.\n',
#  'Oh, OK.\n',
#  'Uh-uh. See, I see.... big passion in your future.\n',
#  "It's fine, it's fine. Look, do you wanna get this part, or not? Here.\n",
#  'Hey!\n',
#  "No it's not. It's small. It's tiny. It's petite. It's wee.\n",
#  "That's because I'm in front of them.\n",
#  "Okay, everybody relax. This is not even a date. It's just two people going out to dinner and- not having sex.\n",
#  "I am so sick of guys. I don't want to look at another guy, I don't want to think about another guy, I don't even want to be near another guy. (Ross crosses arms)\n",
#  "I know. It's just such reckless spending.\n",
#  "So how's it going there in Financial Services?\n",
#  'Oh, not much. I-I got a job.\n',
#  '(to Ross) "Big guy?"\n',
#  "What, it's ok when Chandler does it?\n",
#  'Hello? Like he was really gonna send you one? (To Phoebe) She was a big girl.\n',
#  "Oh, Satan's minions at work again...\n",
#  "It's supposed to be that small. It's a pre-appetizer. The French call it an amouz-bouche.\n",
#  "So I have a flaw! Big deal! Like Joey's constant knuckle-cracking isn't annoying? And Ross, with his over-pronouncing every single word? And Monica, with that snort when she laughs? I mean, what the hell is that thing? ...I accept all those flaws, why can't you accept me for this?\n",
#  '...little playthings with yarn?\n',
#  'Where are you guys going? Come on, one more game!\n',
#  "So Rachel, what're you, uh... what're you up to tonight?\n",
#  "Aw, don't do that\n",
#  "Bullwinkle socks. That's so sweet.\n",
#  "What does that mean?   Does he sell it, drink it, or just complain a lot? (Chandler doesn't know.)\n",
#  "That's because as far as my parents are concerned, Ross can do no wrong. Y'see, he's the Prince. Apparently they had some big ceremony before I was born.\n",
#  'My god, Angela.\n',
#  "You are? Ross, I'm sorry..\n",
#  "Look, Rachel, this is poker. I play to win, alright? In order for me to win, other people have to lose. So if you're gonna play poker with me, don't expect me to be a 'nice guy,' OK? Cause once those cards are dealt... (claps hands three times)\n",
#  "(on phone) Excuse me. (covers up phone; to Ross) It's about the job.\n",
#  'Excuse me?!\n',
#  'Just...please tell him.\n',
#  '(ducking) Get down!\n',
#  'I am not wrong.\n',
#  "I couldn't be inner. Monica?\n",
#  'OK.\n',
#  "Her name is Celia. She's not a bug lady. She's curator of insects at the museum.\n",
#  'Good luck.\n',
#  'Chandler, will you just come in already?\n',
#  "You're good.\n",
#  'I don\'t know, birds just don\'t say, "Hello, sit here, eat something."\n',
#  "I said that you had a nice butt, it's just not a great butt.\n",
#  "Wait, did you get to the part about his 'huge throbbing pens'? Tell ya, you don't wanna be around when he starts writing with those!\n",
#  "Hey. How did, uh, how'd it go today?\n",
#  "Look Daddy, it's my life. Well maybe I'll just stay here with Monica.\n",
#  '(to Joey) One more game?\n',
#  'Oh, Monica! Would you stop being such a wuss?\n',
#  'Urse...\n',
#  "(on phone) Yeah, you want 55-JUMBO. Yeah, that's right. That's right, JUMBO with a U, sir. (pause) No, belive me, you don't want me. Judging by his number, I'd be a huge disappointment. (pause) All rightie, bye bye.\n",
#  'Thank you. Thank you so much!\n',
#  'Oh. Then, no.\n',
#  "Yeah. We don't speak. She's like this high-powered, driven career type.\n",
#  'Oh. What?\n',
#  'Was that the cake?\n',
#  'I’ll get it.\n',
#  'Ok, you can not do this to me.\n',
#  "Something went wrong with Underdog, and they couldn't get his head to inflate. So anyway, um, his head is like flopping down Broadway, right, and I'm just thinking... how inappropriate this is. Um, I've got something in my eye, uh, Joey, could we check it in the light, please?\n",
#  'I just feel like someone reached down my throat, grabbed my small intestine, pulled it out of my mouth and tied it around my neck...\n',
#  '(entering quietly) Hey.\n',
#  'Whaddya see?\n',
#  "Hey, you.... So, what's up?\n",
#  'Oh, okay. Send her in.\n',
#  "So you're free Thursday, then.\n",
#  'Oh, ok bye-bye.\n',
#  "Y'know, I know it's totally superficial and we have absolutely nothing in common, and we don't even speak the same language but Goooooooddddddd....\n",
#  '(as Rachel) Hi.\n',
#  'Need a new table.\n',
#  'Show them to me!\n',
#  'Do you really want a job with Popular Mechanics?\n',
#  'Oh, yeah, check it. Definitely, I want some of that.\n',
#  "Hi, uh, I'll be reading for the role of Mercutio.\n",
#  "Bob? Who the hell's Bob?\n",
#  'Change!  Okay, sit down. (Shows Paul in) Two seconds.\n',
#  'Oh... Oh, Pheebs.\n',
#  "(clutching a beer can and sniffing) This was Carol's favorite beer. She always drank it out of the can, I should have known.\n",
#  'Yes! And that would be a shut-down!\n',
#  'I have no idea.\n',
#  'Oh, I uh, just came by to pick up my skull. Well, not mine, but...Susan: Come in.\n',
#  'Yeah. Cushions the blow.\n',
#  'Thank y... (thinks about it)\n',
#  '(to Phoebe) Would you stop?\n',
#  "Oh, Joey, please tell me you're only donating your time.\n",
#  'Oh, how’d she take it?\n',
#  "Oh, she wants to see me tomorrow...Oh, she sounded really weird, I gotta call Barry... (Does so, on phone) Hi, it's me, I just.. Mindy!! Mindy! Hi! No, I figured that's where you'd be!\n",
#  "Ok, I'm off to talk to my unborn child.\n",
#  "That's so funny, 'cause I was thinking you look more like Joey Tribbiani, man slash woman.\n",
#  '(triumphantly) The Unbearable Likeness of Being!\n',
#  'Yeah, but did they have to shoot him down? I mean, that was just mean.\n',
#  "Wha, heh, how could you know, I don't even know!\n",
#  'No, no, Dad, I was just wondering.\n',
#  'Hey, hey, hey, hey, quit making up rules!\n',
#  'Last time I do that, I promise.\n',
#  "No, it doesn't, does it? But you wanted lumps, Ross? (picks up the pan of badly burnt potatoes) Well, here you go, buddy, ya got one.\n",
#  "What's up man?\n",
#  'No, you?\n',
#  "Yeah, I know, he's sweet, but it's just not fun anymore, you know? I don't know if it's me, or his hunger strike, or, I don't know.\n",
#  'And this from the cry-for-help department. Are you wearing makeup?\n',
#  "It's just a fur ball.\n",
#  '(innocently) What?\n',
#  "Well, go over to her! She's not with anyone.\n",
#  'Guys! Guess what, guess what, guess what, guess what!\n',
#  'Hey, Pheebs.\n',
#  'Yes, every single one of them.\n',
#  "Uh, nothing, I'm sure they'll be impressed with your excellent compuper skills.\n",
#  'Marcel?\n',
#  'She is unbelievable, our mother is...\n',
#  'No I didn\'t. I asked, "got the ke-eys?"\n',
#  "Hey, you guys in the living room all know what you want to do. You know, you have goals. You have dreams. I don't have a dream.\n",
#  'She lent me an egg once.\n',
#  "Oh, it's okay, it was just my left leg.\n",
#  "(getting up, upset) I'm calling Mom.\n",
#  "I'm outta here. Here's my credit card. Dinner's on me. I'm sorry, Chandler.\n",
#  'Petrie.\n',
#  "Alright, well, I'm gonna order a pizza. (gets up)\n",
#  'No, nothing like that. I was just...such a dummie. I taught this "massage-yourself-at-home-workshop." And they are.\n',
#  'Come on, you made coffee!   You can do anything! (Chandler slowly tries to hide the now dead plant from that morning when he and Joey poured their coffee into it.)\n',
#  "Oh, now, don't listen to him, Pheebs, I think it's endearing.\n",
#  'Which, by the way, is the real San Francisco treat. (Calls her, then hurriedly hangs up.) I got her machine.\n',
#  "Janice. Hi, Janice. Ok, here we go. I don't think we should go out anymore. Janice.\n",
#  "Yeah! You know all those yummy noises? I wasn't faking.\n",
#  "Hey Ross. This probably isn't the best time to bring it up, but you have to throw a party for Monica.\n",
#  "Oh, look, he's closing his eyes again.\n",
#  "Yeah, well, I only have twenty minutes until Ethan, so, y'know.. (He starts to raid the fridge.)\n",
#  '(proud) I know, but, I made a huge mistake. I never should have broken up with her. Will you help me? Please?\n',
#  'No, give me the...\n',
#  '(into phone) Pants and a sweater? Why, mom? Who am I gonna meet in a blackout? Power company guys? Eligible looters? Could we talk about this later? OK. (hangs up)\n',
#  'Does anyone want the rest of this Pop-Tart?\n',
#  'Ok, yeah, ok. (she throws the directions in) Oh, OK.\n',
#  "Come on, come on. Damnit, damnit, damnit, damnit. (to Susan) This is all your fault. This is supposed to be, like, the greatest day of my life, y'know? My son is being born, and I should be in there, you know, instead of stuck in a closet with you.\n",
#  "You're wrong.\n",
#  'Here goes. (He walks over to her but just stands there.)\n',
#  "Thanks. Hi, um, 'kay. I'd like to start with a song that's about a man that I recently met, who's, um, come to be very important to me. (Monica gives her a look) 'Kay. (Sung:)\n",
#  'Well, isn’t, isn’t that gonna be weird?\n',
#  "(on phone) Could you please tell me what this is in reference to? (Listens) Yes, hold on. (To Rachel) Um, they say there's been some unusual activity on your account.\n",
#  'I wish all guys could be like him.\n',
#  'What?\n',
#  'I gave you one job! (Starts to examin the lasagne through the bottom of the glass pan.)\n',
#  "Wo-wo-whoa. What about Phoebe's birthday?\n",
#  'Sure, why not?\n',
#  'Why not?\n',
#  'I know, I still am one of these.\n',
#  'Ok, right about now the turkey should be crispy on the outside, juicy on the inside. Why are we standing here?\n',
#  "Oh, okay, I don't know what you just said, so let's get started.\n",
#  'Yeah? What does she think of your little science project?\n',
#  "Rachel, there's nothing in it.\n",
#  "This Alan again? How's it goin'?\n",
#  'We, we come back from our walk and the- the phone was ringing...\n',
#  "Oh, I was hoping you wouldn't remember.\n",
#  'They’re twins!\n',
#  'And Monica knows...\n',
#  'Oh no, you see, actually it is.\n',
#  "What's going on here? You go out with tons of girls.\n",
#  "Oh, OK, so then what is it? Some kind of... you know, like, like... some kind of, y'know, like... alright, what is it?\n",
#  'Really?\n',
#  'Unless...\n',
#  "Oh, that's fine, no.\n",
#  "Uh...no. No, no, in fact, you're not having a boy.\n",
#  '(overhearing) What kind of research?\n',
#  "(squatting and reading the instructions) I'm supposed to attach a brackety thing to the side things, using a bunch of these little worm guys. I have no brackety thing, I see no whim guys whatsoever and- I cannot feel my legs.\n",
#  'Guys! Guess what, guess what, guess what, guess what!\n',
#  'Monica, would you calm down? The credit card people said that you only have to pay for the stuff that you bought.\n',
#  'Oh, no, no. Nina... (miming fairies twinkling around his head) ..she is whooo wewee-woo whoo whoo! In fact, if you asked her right now, she would have no recollection of being fired at all, none at all.\n',
#  "Oh, Satan's minions at work again...\n",
#  'You are not putting that on again! Marcel, OK—if you press that button, you are in very, very big trouble.\n',
#  "Yeah, at Macy's. You were the Obsession girl, right? I was the Aramis guy. (pretends to spray cologne) Aramis? Aramis?\n",
#  'Oh, I wanna see! Lemme see! Lemme see! (She runs up and takes the binoculars.)\n',
#  'I know this is going to sound unbelievably selfish, but, were you planning on bringing up the whole baby/lesbian thing? Because I think it might take some of the heat off me.\n',
#  "Okay. It's-it's about Alan. There's something that you should know. I mean, there's really no easy way to say this.. uh.. I've decided to break up with Alan.\n",
#  "Hell no, we'll pay!\n",
#  'Why not?\n',
#  'Oh.. a little..\n',
#  'I remember the day I got my first pay check. There was a cave in in one of the mines, and eight people were killed.\n',
#  "Yeah. I'm thinking, if we put our heads together, between the two of us, we can break them up.\n",
#  'What does she mean?\n',
#  'Yes.\n',
#  'Oh, please, that is such a lame excuse!\n',
#  'Ha, I made you look....\n',
#  'Why?! Why? Why, why would anybody do something like that?\n',
#  "Oh, so what you're saying is you're not completely fulfilled by Rick, Ethan and myself?\n",
#  "Okay, umm-umm, I'll just--I'll be right back, I just gotta go ah, go ah...\n",
#  'No, I just talked to them.\n',
#  'And then, like three days in a row he got to the newspaper before I did, and peed all over the crossword.\n',
#  'I need some milk.\n',
#  "You're not a senior?\n",
#  'That oughta do it.\n',
#  'I, er...\n',
#  'Well, I never call me.\n',
#  'I got it.\n',
#  'We all chipped in.\n',
#  "Don't you have a laundry room in your building?\n",
#  'Then why the hell are you dumping my brother?!?\n',
#  '(as Monica) And by the way, have I mentioned that back in high school, I was a cow?\n',
#  "I just wan't to...\n",
#  "Man, hell of a two weeks, huh? Y'know what, though? I really feel like I learned something.\n",
#  "And here we have the last of Paulo's grappa.\n",
#  "When's that?\n",
#  'Where have you been?\n',
#  "I don't know. You dumped her on New Year's.\n",
#  "I-I'm, I'm having a boy?\n",
#  'So.... I quit.\n',
#  "I don't know. We're talking about whipped fish, Monica. I'm just happy I'm keeping it down, y'know?\n",
#  "Hello? (Listens) Um, yeah, uh, (snapping her fingers at Ross who takes the remote from Marcel, then turns off the TV) Okay ah, hold on a second, lemme lemme just check and see if see if she's here.\n",
#  "Shh! (singing) Here we come, walkin' down the street, get the funniest looks from, everyone we meet. Hey, hey! (to Carol) Hey, uh, did you just feel that?\n",
#  "Ok. (browsing the apartment) Wow, you guys sure have a lot of books about bein' a lesbian.\n",
#  'Hey.\n',
#  "All right, fine. Tonight's potatoes will be both mashed with lumps, and in the form of tots.\n",
#  "(in baby-like voice) How come you don't live with Mommy? (pause; shows Ross less than amused) How come Mommy lives with that other lady? (pause; Ross still looks less than amused; Joey smiling) What's a lesbian? (playfully hits Ross)\n",
#  'That sounds like Nana.\n',
#  "And you've got lenses! But you hate sticking your finger in your eye!\n",
#  '(Looking out at the balcony) So tell me something, is leaving the Christmas lights up part of your plan to keep us merry all year long?\n',
#  "Hey, look, we're on that TV thing!\n",
#  "Well maybe it's cold in there. Or maybe I screwed up the first date I had in 9 years.\n",
#  '(entering with Paolo, arm in arm) Everybody, this is Paolo. Paolo, I want you to meet my friends. This is Monica.\n',
#  'And (he imitates the buzzer) to you too, Helen.\n',
#  'How many you want?\n',
#  "Okay, but Pheebs, Pheebs, Jack gave up a cow, I gave up an orthodontist. Okay, I-I-I know, I know I didn't love him-\n",
#  "Who cares, we'll eat at the sink! Come on, let's play!\n",
#  'Yes.\n',
#  "He doesn't have anyone.\n",
#  'Joey ate my last stick of gum, so I killed him. Do you think that was wrong?\n',
#  "Well, I just lost a job, and I'd like to raise the bet five bucks. Does anybody have a problem with that?\n",
#  '(gets up) OK, how does everybody like their burgers?\n',
#  'I’m sayin’ I see a difference.\n',
#  "No you don't.\n",
#  'Heh... I was bluffing.\n',
#  '(smiling)....with??\n',
#  'No.\n',
#  "(finishing changing Chandler's nicotine patch) There y'go.\n",
#  'We forgot to sign one of the admissions forms.\n',
#  "Uh, it's 2:30 in the morning!\n",
#  'What... I could, I could do it. What is it?\n',
#  "Alright. There's a theory, put forth by Richard Leakey-\n",
#  "(with a deep voice) Mr. Bing's office. (Listens) No I'm sorry, he's in a meeting right now.\n",
#  'Hi Pheebs!\n',
#  'Set another place for Thanksgiving. My entire family thinks I have VD.\n',
#  "You can see where he'd have trouble.\n",
#  "Here's a little tip, she really likes it when you rub her neck in the same spot over and over and over again until it starts to get a little red.\n",
#  "Rach, here's your mail.\n",
#  'Oh, OK.\n',
#  'Hell is filled with people like you.\n',
#  "Relax. You're only at nine centimeters. And the baby's at zero station.\n",
#  'What is this?!\n',
#  'Wh- are you welling up?\n',
#  'Look at that!\n',
#  "Uhhhh.... I'll just pee in the street.\n",
#  'No... no! And yet it did. Good-bye, Janice.\n',
#  "(Tiny laugh) yep, that's me, (tiny laugh) I am that stupid (tiny laugh).\n",
#  '(wiping his brow) Ah...ooh! Well, looks like, uh, we kicked your butts.\n',
#  'What?\n',
#  'Oh, well, ah... maybe that’s because they’re ah... jealous, of us.\n',
#  'Hi, Just Janice.\n',
#  'Why?\n',
#  'I’m gonna be a father.\n',
#  'Hey!\n',
#  'Shut up!\n',
#  '(to Ross) Let me get you some coffee.\n',
#  'Career counselor?\n',
#  "I don't know. It's just not the same without Mom in the kitchen.\n",
#  'Guess what?\n',
#  "Go Monana! Well, you ladies are not the only ones living the dream. I get to go pour coffee for people I don't know. Don't wait up. (Exits)\n",
#  'You guys okay?\n',
#  'Or?\n',
#  "You know, did you ride mopeds? 'Cause I've heard... (they stare at her)... oh, I see... it's not about that right now. OK.\n",
#  "I'm so sorry, I can't believe I did this, but I couldn't stop laughing at your Norman Mailer story.\n",
#  'Anybody wanna trade? Oh...\n',
#  "Well, we're applying to a lot of them. Naturally our first choice would be one of the bigger state zoos, y'know, like, uh, San Diego... right? But that might just be a pipe dream, because, y'know, he's out of state. Uh, my vet, uh, knows someone at Miami, so that's a possibility.\n",
#  '(Closing the door) Goodbye Mr.Heckles.\n',
#  'No. Oh, oh, I guess it would be different if I were- with somebody.\n',
#  'Mmmm.\n',
#  "Yeah, yeah, it's just that with my last roommate Kip...\n",
#  'Nah... not-not special enough.\n',
#  "(bursts out laughing again) I can't believe you didn't know it was a line!\n",
#  "Alright. (He goes to get the glasses. Then he hesitates and turns off the main light. Rachel looks round and he acts surprised) The, uh, the neighbours must be vacuuming. (He sits down and starts to pour the wine) Well, so long as we're here and, uh, not on the subject, I was thinking about, uh, how mad we got at each other before, and, um, I was thinking maybe it was partially because of how we, um...\n",
#  "It was unbelievable. I-I've never met anyone like her. She's had the most amazing life! She was in the Israeli army...\n",
#  "I can't remember the last time I got a girl to take care of my monkey.\n",
#  'Um you, you got a minute?\n',
#  "I honestly don't know if I'm hungry or horny.\n",
#  'Services? (Ross looks at him) Oh, services.\n',
#  'Hey, when did you and Susan meet Huey Lewis?\n',
#  "G'bye, Nana. (She kisses her on the forehead.)\n",
#  'You know what?\n',
#  '...I can imagine.\n',
#  'Okay..\n',
#  "(reading Monica's palm) No, 'cause this line is passion, and this is... just a line.\n",
#  "(sarcastically) And you didn't marry him because...?\n",
#  '(singing)\n',
#  "Let her know I like her? What are you, insane? (The girls make disgusted noises.) It's the next day! How needy do I want to seem? (To the guys) I'm right, right?\n",
#  '59 seconds. (holds up his watch) Quartz, ha.\n',
#  "Marcel is an illegal exotic animal. I'm not allowed to have him in the city. If they find him, they'll take him away from me.\n",
#  'The actress!\n',
#  'Ross, that’s my jacket.\n',
#  "I-I'm, I'm having a boy?\n",
#  'That is so sweet, you guys. (hugs them)\n',
#  'Relax your hand!\n',
#  "Burning's good. Yeah, I got stuff to burn.\n",
#  'Yeah, you too.\n',
#  'God, what a great day. ...What? Weather-wise!\n',
#  'Pete the Weeper? Remember that guy who used to cry every time we had sex. (imitating) "Was it good for you?"\n',
#  "This is so unfair! She's got everything I want, and she doesn't have my mother.\n",
#  "(hums for a while, then gives up, and in her head) If it bothers you that much, just go out and get the shoes. No. Don't do this. This is stupid! I don't have to prove anything, I'm gonna go get them...But then everyone will know. Unless I get them, and then wake up really early and put them back! ...I need help! (She buries her head in her pillow.)\n",
#  "Oh c'mon! When we were kids, yours was the only Raggedy Ann doll that wasn't raggedy!\n",
#  'Excuse me? Can I help you with anything?\n',
#  "We just finished this magnificent Thanksgiving dinner. I have--and I remember this part vividly--a mouthful of pumpkin pie, and this is the moment my parents choose to tell me they're getting divorced.\n",
#  'My God.\n',
#  '(answering phone) Hel-lo, Rachel Green.\n',
#  'Ok, ok, here we go. (he crouches down near her stomach) Ok, where am I talking to, here? I mean, uh, well, there is one way that seems to offer a certain acoustical advantage, but...\n',
#  'Oh. Hi, Mr.Heckles.\n',
#  'Uh, hi. We uh, we used to work together.\n',
#  'Yes, Bunny?\n',
#  "Um, oh, I've got a birthday party, with some work people.\n",
#  '(to Ross): Loser?\n',
#  'Then why the hell are you dumping my brother?!?\n',
#  'What?\n',
#  "C'mon, you can't live off your parents your whole life.\n",
#  "Ooh, ok, that's it. Enough with the keys. No one say keys.\n",
#  'Hi.\n',
#  'It is so great to meet a guy who is smart and funny, and has an emotional age beyond, like eight.\n',
#  'Sure, why not?\n',
#  'Here we go.\n',
#  'Lots of responses.\n',
#  'Well, is it, like, a little annoying, or is it like when Phoebe chews her hair?\n',
#  "You don't drink.\n",
#  'Well, we both have.\n',
#  'You still on that?\n',
#  'Aww. Thank you, Aunt Phoebe.\n',
#  'Well... of course I thought of you! But... but...\n',
#  'Sure.\n',
#  'Michael.\n',
#  'What?\n',
#  'No, why?\n',
#  'Could tonight be the Night?\n',
#  'So how are things going with you two? Is she becoming your (provocatively) special someone?\n',
#  "Well, my secretary is gonna be out for a couple of weeks. She is having one of her boobs redused. (Ross looks at her.) It's a whole big boob story.\n",
#  '...pig...pig man!\n',
#  'Waaay too special.\n',
#  '(grins and walks to the kitchen and says to Chandler and Joey.) I helped!\n',
#  'Pheebs, you remember how we talked about saying things quietly to yourself first?\n',
#  'Ow ow ow. Ow ow ow ow. Ow ow ow. Ow. Ow. Ow. Ow.\n',
#  "Whoah, boy, hockey was a big mistake! There was a whole bunch of stuff we could've done tonight!\n",
#  'Still, you- you say Minnie, you hear Mouse. Um, how about, um.. how about Julia?\n',
#  "Ok, ok, ok, ok, here goes. You know, I, you know, can't do this. Uh, this is too weird. I feel stupid.\n",
#  'A couple hours.\n',
#  "Yeah. It's Dutch.\n",
#  'You know, you and Bob, and me and my girlfriend, uh, uh, Monica.\n',
#  "What's goin' on?\n",
#  "I'm serious. You're amazing. You know when to spritz, when to lay back.\n",
#  "Would you let it go? It's not that big a deal.\n",
#  "So how does this work, you going to balance the plates on these little guys' heads?\n",
#  "Well, maybe that's my decision. Well, maybe I don't need your money. Wait!! Wait, I said maybe!!\n",
#  "Hi, um, I'm account number 7143457. And, uh, I don't know if you got any of that, but I would really like a copy of the tape.\n",
#  '(to Steve) This is Rachel.\n',
#  '(returns) Yeah, alright.\n',
#  'Breathe.\n',
#  'Why?\n',
#  'Which ones?\n',
#  'Funny, my birthday was seven months ago.\n',
#  'Okay, Pheebs, can I ask? So, he’s going out with her. I mean, is it really so terrible?\n',
#  "Ok, ok, ok, ok, here goes. You know, I, you know, can't do this. Uh, this is too weird. I feel stupid.\n",
#  'Wait, wait, wait!\n',
#  '...medium...hmm...any cookies left?\n',
#  'Okay, quick and painful. (Starts to cork the wine)\n',
#  "Me either... (He pulls up a stool so that he doesn't have to move his hand.)\n",
#  'Hey, I might!\n',
#  'Really? Just casually strewn about in that reckless haphazard manner?\n',
#  'Yeah, well, is that better?\n',
#  'Well, what happened?\n',
#  'I did.\n',
#  'Mindy?! My maid of honour, Mindy?!\n',
#  '(panicked) The oven is on.\n',
#  "Oh, hello, kettle? This is Monica. You're black.\n",
#  "..You're, you're 'mah mah mah' what?\n",
#  'What do you mean?\n',
#  'Oh, you must stop shooping.\n',
#  'Oh, big glamour night. Me and Monica at Laundorama.\n',
#  '(sticking her foot out) Hm-m.\n',
#  'I got you the foot massager.\n',
#  "You have to tell her! You have to tell her! It's your moral obligation, as a friend, as a woman, I think it's a feminist issue! Guys? Guys? (waiting for guys to chime in)\n",
#  'Wait here. Breathe.\n',
#  "'The hills were alive with the sound of music.'\n",
#  'Nuh-uh.\n',
#  "Yeah, I mean... I think when it's your shot, y'know, you-you know it's your shot. Did it... feel like your shot..?\n",
#  "She's living my life, and she's doing it better than me! Look at this, look. She buys tickets for plays that I wanna see. She, she buys clothes from stores that I'm intimidated by the sales people. She spent three hundred dollars on art supplies.\n",
#  "That's the rule.\n",
#  'Oh... (opens it)... (sees it is a pin) Oh my God. He remembered.\n',
#  "Well, let's just say the impressions you made in the butter left little to the imagination.\n",
#  "Sure, every time, you're such a princess...\n",
#  "How would I know? I-I wasn't here.\n",
#  'Um, is it sugarless?\n',
#  "I'm telling you, that monkey is a chick magnet! She's going to take one look at his furry, cute little face and it'll seal the deal.\n",
#  "Yeah, but did you see the dents in his knuckles? That means he's artistic.\n",
#  "Yeah, but you were the one who got him back, y'know? You, you were great. ...Hey, we uh, we still have that, uh, that bottle of wine. You in the mood for, uh, something grape?\n",
#  "All right, fine. Tonight's potatoes will be both mashed with lumps, and in the form of tots.\n",
#  'If you wanna put a label on it.\n',
#  'Monica, in or out?\n',
#  'Let’s not do that any more.\n',
#  '(Into mike) Okay, that was Phoebe Buffay, everybody. Woo!\n',
#  '...medium...hmm...any cookies left?\n',
#  'Why would I have the keys?\n',
#  'So.\n',
#  'Aw, right.\n',
#  'Hi.\n',
#  'You missed a belt loop.\n',
#  "I know, I just want to bite his bottom lip. (Rachel looks at her) But I won't.\n",
#  "No, no, no... why, because it might get weird for everyone else? Who cares about them. This is about us. Look, I-I've been in love with you since, like, the ninth grade.\n",
#  "Nononononono. Think who you're dealing with here. I mean, I'm not like you. I-I can't even stand in front of a tap class.\n",
#  "I'm trppd... in an ATM vstbl... wth Jll Gdcr!\n",
#  'Yeah, but did they have to shoot him down? I mean, that was just mean.\n',
#  "(from the air vent overhead) You guys, he's beautiful!\n",
# ...
#  'Oh.\n',
#  'Not from where I was standin’.\n',
#  'Marcel?\n',
#  'Well, you were pretty damn good.\n',
#  'Hi!\n',
#  '(reading): OK... Dear Ms. Green... yeah... yeah... yeah... No. (crumpes up letter)\n',
#  'All right, you guys, I kinda gotta clean up now. (They all start to leave.)\n',
#  "Um, I'm not actually Amish.\n",
#  '(weakly) No.\n',
#  'Monica? Monica!\n',
#  '(in disbelief) Vulva?\n',
#  'Come on, we were great together. And not just at the fun stuff, but like, talking too.\n',
#  'Ha. Ha, ha.\n',
#  "Who wasn't invited to the wedding.\n",
#  'Wow, being dumped by you obviously agrees with her.\n',
#  'Did not.\n',
#  'Huh.\n',
#  'I don’t care. Phoebe’s Phoebe. Ursula’s... hot!\n',
#  "'S'funny, um, uh, we agreed we'd spend the rest of our lives together. Things change, roll with the punches. I believe Julia's on the table..?\n",
#  "I don't know. Maybe I'll know when I see him.\n",
#  'That is so unfair!\n',
#  'Oh, yeah, yeah. Actually, I got the extended disco version, with three choruses of "You\'ll never make it on your own".\n',
#  "Wait—oh—hey—huh, oh great now he knows, and I don't know!\n",
#  "Great, now he's waving back.\n",
#  "Okay. Okay, we'll be here! Hating you! Did you see how he was sweating when he walked out of there? Listen honey, if I'm hogging the ball too much you just jump right in there and take a couple punches because I'm telling you, this feels great.\n",
#  'What?\n',
#  "(draws back) Really. Mindy, if it'll make you feel any better, when I was engaged to him he went through a whole weird thing too.\n",
#  "All right, kids, I gotta get to work. If I don't input those numbers,... it doesn't make much of a difference...\n",
#  'Pheebs, why would you want to operate a drill press?\n',
#  "I'm having a baby in here! Ok, everyone stand back. (Walks backwards as if he is going to break down the door, but steps in a bucket and falls) Ow.\n",
#  'Say it... say it!\n',
#  'Oh, okay. Will you take my place?\n',
#  'What?!\n',
#  'Oh yeah? And who do you like?\n',
#  "Man, if you tried something like that on my birthday, you'd be starin' at the business end of a hissy fit.\n",
#  'I love babies, with their little baby shoes, and their little baby toes, and their little baby hands...\n',
#  "Oh.. you don't get it! (Passes out and slumps across her)\n",
#  "No, no, no. They say it's the same as the distance from the tip of a guy's thumb to the tip of his index finger.\n",
#  'And I assume, Chandler, you are still boycotting all the pilgrim holidays.\n',
#  "I was really upset about Rachel and Paolo, and I think I had too much tequila, and Nora- um, Mrs. Mom- your Bing- was just being nice, y'know, and- But nothing happened, nothing- Ask Joey, Joey, uh, came in-\n",
#  'I see your twenty, raise you twenty-five. (throws it in)\n',
#  'I was laughing! You made me laugh! (Monica and Rachel start to squabble)\n',
#  'You-you had what?\n',
#  "I mean, why should I let them meet him? I mean, I bring a guy home, and within five minutes they're all over him. I mean, they're like- coyotes, picking off the weak members of the herd.\n",
#  'Thank you. (Examines it) Oh, cool! Free sample of coffee!\n',
#  "And, we're done with the yogurt. (Sets yogurt down on table)\n",
#  'Popes in a Volkswagen! ...I love that joke.\n',
#  "(points at Joey's pen) Uh, uh, gimme. Can you see me operating a drill press?\n",
#  'Yeah, get out!\n',
#  '(hurt) Waitressing?\n',
#  "Come on, you know, Thanksgiving. Ooh, you got the bigger half. What'd you wish for?\n",
#  'Okay, you guys spend waaaay too much time together. (Goes back inside and shuts the door)\n',
#  "You have to tell her! You have to tell her! It's your moral obligation, as a friend, as a woman, I think it's a feminist issue! Guys? Guys? (waiting for guys to chime in)\n",
#  "No, no. Uh... no, see, uh, you-you can't do that.\n",
#  "No, it's not just that. It's just—I want someone who... who does something for me, y'know? Who gets my heart pounding, who... who makes me, uh... (begins to stare lovingly at Rachel)\n",
#  'Huh.\n',
#  "(to Monica): Could you take it to Carol's every now and then, and show it to Ben, just so he doesn't forget me?\n",
#  'What was with the dishes?\n',
#  '(spitting out her drink in shock) Oh God, oh God, I am sorry... I am so sorry...\n',
#  "I- I think they're great! I, I really do.\n",
#  'Joey, please.\n',
#  'Why?\n',
#  'Look out, incoming pumpkin pie!\n',
#  'Hey, hey.\n',
#  'Hi, I thought you might like some ice chips.\n',
#  'Do it!\n',
#  "No, actually I was just saying it looks like we're not sitting together. But now you mention it, there was ice there that night... It was the first frost...\n",
#  'Last night.\n',
#  'You wanna watch Laverne y Shirley?\n',
#  'Well, what about Mindy?\n',
#  'Yeah\n',
#  'So, Saturday night, the big night, date night, Saturday night, Sat-ur-day night!\n',
#  'You be okay?\n',
#  "Joey, what's going on?\n",
#  'Oh, wow, so you\'re gonna be one of those "healthy, healthy, healthy guys"?\n',
#  'No, women are welcome to play.\n',
#  "Uh, I'm not really a shot drinking kinda guy.\n",
#  "How'd you know I was coming?\n",
#  'This is nice. We never do anything just the two of us.\n',
#  'Holden McGroin.\n',
#  'Don\'t stare. Now she just finished throwing his clothes off the balcony, now there\'s just a lot of gesturing and arm-waving, (shows Rachel gesturing with hands in front of her chest), Ok, that is either, "How could you?" or, "Enormous breasts!" Here he comes!\n',
#  "Ooh! That's so nice...\n",
#  "C'mon, you guys, it wasn't that bad. It was better than that thing I did with the trolls, at least you got to see my head.\n",
#  'Oh.... my God.\n',
#  'Big time!\n',
#  'What are you guys doing here?\n',
#  "There, well, see? Barry wouldn't even kiss me on a miniature golf course.\n",
#  "Y'think?\n",
#  'Do what, do what?\n',
#  'Hey.\n',
#  'Why would I tell him?\n',
#  "Hey, that's... that's 'joincidence' with a 'C'!\n",
#  'Can we come in?\n',
#  'I just never had a relationship with that kind of passion, you know, where you have to have somebody right there, in the middle of a theme park.\n',
#  'Hey, Phoebe, I asked you, and you said it was okay.\n',
#  'How-how are you, Mom?\n',
#  'Remembered what?\n',
#  'Ooh...hey honey, are you all right?\n',
#  "Heh, heh. It was nothin'.\n",
#  'What?\n',
#  'Ok, Ok, Pheebs...\n',
#  'Hello.\n',
#  'The girl on the cover with her nipples showing?\n',
#  "(puts down the lasagne) I just... can't do it.\n",
#  "Well, he came in for a massage, and everything was fine until. (A flashback starts Paolo, lying on massage table, moving his hands up Phoebe's legs.)\n",
#  "I can't remember the last time I got a girl to take care of my monkey.\n",
#  'Hey.\n',
#  "Okay, look, this is probably for the best, y'know? Independence. Taking control of your life.  The whole, 'hat' thing.\n",
#  'Oh, I uh, just came by to pick up my skull. Well, not mine, but...Susan: Come in.\n',
#  "(interrupts) No, no, no I don't want to know, don't want to know. Ok, you know, I should probably, I should probably just go.\n",
#  'Green. To the green.\n',
#  "Luisa? Oh my God! Monica! It's Luisa!\n",
#  "Who's Rick?\n",
#  'No, not even close. Forget Vail, forget seeing my family, forget shoop, shoop, shoop.\n',
#  "Yes, yes, it does. Okay, look, the restaurant called, they wanna know if you're gonna be showing up for work?\n",
#  'Hah, no no no no no no no no no no.\n',
#  "Yes, my sister's giving us her place for the weekend.\n",
#  'Yeah, I know! (turns to Chandler) So, what do you think?\n',
#  "Oh, no I don't.\n",
#  "Oh God, oh. Great, Monica, y'know what, you could've called, I have been up here, I've been worried...\n",
#  'Ooh! How about Agamemnon?\n',
#  'Yeah. (They go to the kitchen.)\n',
#  "No, it is me! Y'know, I'm not just the person who needs to fluff the pillows and pay the bills as soon as they come in! Y'know, when I'm with her, I am so much more than that. I'm- I'm Monana!\n",
#  'Okay, gimme my monkey back.\n',
#  "(sarcastic) I don't see why not.\n",
#  "Oh, god, this is great! The plane is gone, so it looks like I'm stuck here with you guys.\n",
#  'Uh, we are here to break up with you.\n',
#  'Uh, Joey..\n',
#  "Oh, well, see, there's this guy she met at the...\n",
#  'Well, I mean, I’m not my sister’s, you know, whatever, and um... I mean, it’s true, we were one egg, once, but err, you know, we’ve grown apart, so, um... I don’t know, why not? Okay.\n',
#  "(picking up a leftover part) What's this?\n",
#  "What's up with the simian?\n",
#  'Yeah. Cushions the blow.\n',
#  "Okay, see, see, you guys, what if we don't get magic beans? I mean, what if all we've got are.. beans?\n",
#  "You're good.\n",
#  'And Mindy, your maid of...?\n',
#  "(entering) How's it going?\n",
#  "Yes, and her boyfriend. But we're celebrating Thanksgiving in December 'cause he is lunar.\n",
#  'Right. No big deal.\n',
#  "It's so that I can spend Thanksgiving with my family. See, every year we go skiing in Vail, and normally my father pays for my ticket, but I sort of started the whole independence thing, you know, which is actually why I took this job.\n",
#  'I read to you.\n',
#  "I'm fine.\n",
#  'It was my first time.\n',
#  "Yeah, I think we're ready for our first course. (Steve sits, Monica brings over a tray) OK, um, these are rot-shrimp ravioli, and celantro pondou sauce... (Steve starts to eat them one by one, quickly)... with just a touch of mints... and... (he finishes)... ginger.\n",
#  "So you don't think I have a, a quality?\n",
#  '(angry) Joey!\n',
#  "They're here already?\n",
#  'Is it me? Is it like I have some sort of beacon that only dogs and men with severe emotional problems can hear?\n',
#  "Isn't this amazing? I mean, I have never made coffee before in my entire life.\n",
#  'Tony?\n',
#  "OK, I have a question. Well, actually, it's not so much a question as.. more of a general wondering... ment.\n",
#  '(deadpan) Please be kidding.\n',
#  'Ah, the forbidden love of a man and his door.\n',
#  'Oh really, so that hysterical phone call I got from a woman at sobbing 3:00 A.M., "I\'ll never have grandchildren, I\'ll never have grandchildren." was what?  A wrong number?\n',
#  'My god, Angela.\n',
#  "You're not an artist.\n",
#  "That's not a question.\n",
#  "(to Joey) So he's calling from Rome. I could do that. Just gotta go to Rome.\n",
#  'Oh my God.\n',
#  'What are you doing?\n',
#  'Alright, now try taking a puff.\n',
#  'What?\n',
#  'I just wanna clarify this: are you outing Mr. Peanut?\n',
#  "Yeah, well, I still got a week left to go in the program, and according to the rules, if I want to get the money I'm not allowed to conduct any... ersonal experiments, if you know what I mean.\n",
#  "Would you excuse me, please? I'm trying to have a date here.\n",
#  '59 seconds. (holds up his watch) Quartz, ha.\n',
#  'What?\n',
#  "Um, that's really your decision, I mean, some people prefer, you know, to take off...oh whoops! You're being naked!\n",
#  "(deals new hand) Boy, you really can't stand to lose, can you? Your whole face is getting red... little veins popping out on your temple...\n",
#  "I don't know... sometimes it doesn't.\n",
#  "I'm having a son. Um...\n",
#  "I don't know. We're talking about whipped fish, Monica. I'm just happy I'm keeping it down, y'know?\n",
#  "Oh, hey, y'know what? Tell them that bone story.\n",
#  'Are you sure?\n',
#  '(tastes it) Well.... it is amouz-ing...\n',
#  '(getting angry) What!!?\n',
#  "See ya.... Waitwait, what's with you?\n",
#  '...As in Mouse?\n',
#  "All right, well, you're right, these are the best oatmeal cookies I've ever had.\n",
#  'I can’t believe you. You still haven’t told that girl she doesn’t have a job yet?\n',
#  'Rachel lost Marcel.\n',
#  'What!?\n',
#  'Yeah, like in a cab...\n',
#  "No problem, ok, mmmwa (kisses Carol) oh, mmmwa (kisses Carol's stomach, then punches Susan's shoulder) Susan... (Ross leaves.)\n",
#  'How do you do that?\n',
#  "Hey Ross, listen, you know that right now, your baby's only this big? (measures about 2 inches with his thumb and index finger) This is your baby. (in baby-like voice) Hi Daddy!\n",
#  "Oh no nonononononnononono, don't go.. (He kisses her and pulls her back down.)\n",
#  'Oh my God! Calling from Rome! (Takes phone) Bon giorno, caro mio.\n',
#  "Ok, Janice. Janice. Hey, Janice. Look, there's no way for me to tell you this. At least there's no new way for me to tell you this. I just don't things are gonna work out.\n",
#  '(mimicking Rachel) Mee mee, mee-mee mee.\n',
#  "The uh, the baby that hasn't been born yet? Wouldn't that mean you're... crazy?\n",
#  'That, you get? That, you get?\n',
#  "Hey, hey, ok, all right, that's it! Get in here. Come on. My god, you guys, I don't believe you. There are children coming into the world in this very building and your negative fighting noises are not the first thing they should be hearing. So just stop all the yelling, just stop it!\n",
#  'Yeah, sorry, the swallowing slowed me down.\n',
#  'Check it out, Giants-Cowboys. (He has a pocket TV)\n',
#  "Hey hey hey! She's on!\n",
#  'When we were?\n',
#  'Hey.\n',
#  "All right! I'm putting it out, I'm putting it out. (He drops it in Phoebe's coffee.)\n",
#  "Ugh. (To another customer that's leaving.) Excuse me, could you give this to that guy over there? (Hands him the coffee pot.) Go ahead. (He does so.) Thank you. (To the gang.) Sorry.  Okay, Las Vegas.\n",
#  'Ooh, ooh, fun! Okay... um, Liam Neeson.\n',
#  "Come on, Ross, you gotta get back in the game here, ok? The Rachel thing's not happening, your ex-wife is a lesbian—I don't think we need a third...\n",
#  '"Warden, in five minutes my pain will be over. But you\'ll have to live with the knowledge that you sent an honest man to die."\n',
#  'It’s mostly just dumb sister stuff, you know, I mean, like, everyone always thought of her as the pretty one, you know... Oh, oh, she was the first one to start walking, even though I did it... later that same day. But, to my parents, by then it was like "yeah, right, well what else is new?"\n',
#  "I couldn't do it.\n",
#  "What're you gonna do?\n",
#  'Okay... Okay.\n',
#  'The most unbelievable thing has happened. Underdog has just gotten away.\n',
#  'Tell me what?\n',
#  'Oh, that is so sweet. (Touched, she puts an arm around her friend and kisses her.) Oh gosh, love you. Insurance?\n',
#  "(as Rachel) Yeah... Yeah, I know it's pretty selfish, but haha, hey, that's me. (Indicating a dish on the table) Why don't you try the hummus?\n",
#  'Well, I guess that’s why they call it psychology, sir.\n',
#  'Yeah!\n',
#  'No!\n',
#  'Sometimes I wish I was a lesbian... (They all stare at him.) Did I say that out loud?\n',
#  'Really.\n',
#  'Joey!!\n',
#  "Barbara! Hi, how are you? (Listens) Uh-huh. (Listens) No, I understand. Yeah. Oh, oh, come on, no, I'm fine. Don't be silly. Yeah... oh, but you know, if-if anything else opens up, plea—Hello? Hello? (hangs up phone, very depressed)\n",
#  'What are you mad at me for?!\n',
#  '"Ooo," what?\n',
#  "No, no, trust, me, it's, it's, it's much better that I know. Uh, I just liked it better before it was better...\n",
#  "Hey, I've been honing!\n",
#  "Why did I 'woo-hoo'? I mean, what was I hoping would happen? That-that he'd turn round and say 'I love that sound, I must have you now'?\n",
#  "Well, y'know, monogamy can be a, uh, tricky concept. I mean, anthropologically speaking-\n",
#  'Alright. Well then how about I call your supervisor, and I tell her that you shot my friend in the ass with a dart?\n',
#  'Thanks, you can just put it on the table.\n',
#  'Monica, in or out?\n',
#  "Um, I'm not actually Amish.\n",
#  "So... What's the deal with umm, you and Joey?\n",
#  '(entering from her room) Okay, coming!\n',
#  'Yeah, it was really hard.\n',
#  'You guys okay?\n',
#  'Get him! GET HIM! Get him! Get- YESSS! Not laughing now, are ya pal!\n',
#  'Yeah. (They go to the kitchen.)\n',
#  'Hon, you gotta talk to Joey.\n',
#  "Hell no, we'll pay!\n",
#  "...I'm his (mumbles)\n",
#  'No, you are not. We tell you stuff.\n',
#  "Alright, so I'm back in high school, I'm standing in the middle of the cafeteria, and I realize I am totally naked.\n",
#  '(pulls Monica back) ...and I really think it should be me.\n',
#  "Well, I'm- I'm showering.\n",
#  'For the ride.\n',
#  'You.\n',
#  "Oh. (pause) Hey, who's Carl?\n",
#  'I knew.\n',
#  ...]

# %%
training_labels_final
# Out:
# array([1, 0, 4, ..., 3, 2, 1])

# %%
training_sentences
# Out:
# ["C'mon! Just try to picture her not pregnant, that's all.\n",
#  "Yes! Way to go, man! (Chandler and Ross hug. Something crunches in Ross' shirt pocket.) Still got the egg, huh?\n",
#  'Do they wait for me to do this?\n',
#  "Oh Ross, you're so great. (she playfully rubs his head and gets up)\n",
#  'Uh-oh.\n',
#  'Hey, when did you and Susan meet Huey Lewis?\n',
#  "Um, that's ok! (throws it in fire) Ok. All right. Now we need the semen of a righteous man.\n",
#  'Yes, I know, but her friend sounds like such a...\n',
#  'I swear you said you had the keys.\n',
#  "Yup! You could plunk me down in the middle of any woman's uterus, no compass, and I can find my way out of there like that! (snaps fingers)\n",
#  "Joseph Stalin. I think you'd remember that!\n",
#  'Rach, wait, I can cancel...\n',
#  "Rachel, what's going on? I mean isn't this the same Barry who you left at the altar?\n",
#  "Nice going, imp. OK, it's OK. All I need to do is reach over and put it in my mouth. (Chandler slyly grabs the gum from the wall and slides it back in his mouth.)\n",
#  'Because!\n',
#  'What?\n',
#  'No, we were just laughing. You know, how laughter can be infectious.\n',
#  'Hey.\n',
#  'Yeah.\n',
#  'Well, you should have.\n',
#  'You are just like Jack.\n',
#  'I mean presumably, the biggest part of your job is done.\n',
#  'Okay.\n',
#  "(they shake hands) Hello, Susan. (To Carol) Good shake. Good shake. So, uh, we're just waiting for...?\n",
#  'Does it always, uh--?\n',
#  "(shouting to Chandler) Chandler! He's here!\n",
#  "Yes, yes I did, but what I didn't say was what I was about to say, what I wanted to say was, uh... would you like to go out with me sometime, thankyou, goodnight. (He walks back to the others but she calls him back.)\n",
#  'Relax, I’ll fix it.\n',
#  'So I guess you all saw it.\n',
#  'You know who shaved you? That was me.\n',
#  'At the coffeehouse, right.\n',
#  "Oh, no! I- I can't drink this now!\n",
#  "(exasperated) Yes, Chandler, that's exactly what it is. It's your hair.\n",
#  'Did you ever go out with a guy your friends all really like?\n',
#  "You're a lucky man. You know what I miss the most about her? That cute nibbly noise when she eats. Like a happy little squirrel, or a weasel.\n",
#  'Dad!\n',
#  "No-no-no-no, we're done.\n",
#  'Oh... Milwaukee.\n',
#  'Yeah, yeah, she works over at that place, uh...\n',
#  'Oh, hang on, hang on. Does Aunt Monica get a say in this?\n',
#  'What?! You slept with Jason?\n',
#  'Look, I am totally, totally over her, OK, I just... (Rachel comes over, Ross lays head on table): Hiiii!\n',
#  "You know, they're not actually supposed to have... (Ross looks at her sheepishly) I'll work on the lumps. Joey, you're going home, right?\n",
#  "Don't you realise what you're-you're doing to yourself?\n",
#  'What?\n',
#  'Ohhhh!! (Mindy starts to sob.) ...What? What?\n',
#  "So great! He showed me where the restaurant's going to be. It's this, it's this cute little place on 10th Street. Not too big, not too small. Just right.\n",
#  "All right, I'm nine years old.\n",
#  'Not a good day for birds...\n',
#  "Now she's passed.\n",
#  'See, there you go, the cleansing works!\n',
#  'And then he did.\n',
#  "Please, no, go, that'd be fine!\n",
#  'Wow. Then I would definitely not recommend Mrs. Doubtfire.\n',
#  "I dunno, but.. I think it's about to attack the Enterprise.\n",
#  "Well, well, well, hop back in bucko, cause I got four sixes! (lays down cards) I won! I actually won! Oh my God! Y'know what? (collects chips) I think I'm gonna make a little Ross pile. (holds up a chip) I think that one was Ross's, and I think—oh—that one was Ross's. Yes! (Starts singing): Well, I have got your money, and you'll never see it...\n",
#  '"See you around?"\n',
#  'Can we just start throwing things in?\n',
#  "Hey. How did, uh, how'd it go today?\n",
#  'Oh, listen. If this is about those prank memos, I had nothing to do with them. Really. Nothing at all. Really. (Chandler tries to hide a rubber chicken from the woman.) Nothing.\n',
#  '(Looking out at the balcony) So tell me something, is leaving the Christmas lights up part of your plan to keep us merry all year long?\n',
#  'Do you have a plan?\n',
#  'Well, not... worried, just... wondering.\n',
#  '(quietly) ...spender.\n',
#  "Well, I guess we've established who's staying here with Monica...\n",
#  '(smiling) You betcha!\n',
#  '(sitting) OK.\n',
#  'Yeah\n',
#  "(overemphasizing) Mmmmmm! Everything smells so delicious! You know, I can't remember a time I smelt such a delicious combination of (Monica signals her to stop) of, OK, smells.\n",
#  'That tone will not make me go any faster.\n',
#  "I don't know, but when I spoke to her, she said she had already passed the mucus plug.\n",
#  'What?\n',
#  '...Does the knuckle-cracking bother everybody?\n',
#  "Ok, you weren't there.\n",
#  'Again?\n',
#  "Yeah! Oh, c'mere, Marcel! Oh, Marcel, c'mere!\n",
#  "Ok, um, uh, more clothes in the dryer? (Ross turns and bangs his head on an open dryer door.) I'm fine, I'm fine.\n",
#  'Why? Why would you wanna... do that?  Why?\n',
#  'So what, like people are gonna come in and think, "Uh-oh, I\'m outside again?" Of course!\n',
#  'Jeez, you say one thing, and...\n',
#  "I just can't believe you're in here. I mean, what am I gonna do without you? Who's gonna crash the embassy parties with me? Who's gonna take me to the Big Apple Circus?\n",
#  '(reading): OK... Dear Ms. Green... yeah... yeah... yeah... No. (crumpes up letter)\n',
#  'That tone will not make me go any faster.\n',
#  'Are you gonna go over there?\n',
#  'Hi, is uh, is Carol here?\n',
#  "Okay, is this like 'I have an early class tomorrow' or 'I'm secretly married to a goat?'\n",
#  'You knew about that?\n',
#  '(acts surprised) What? (pause) Why not?\n',
#  "Hey, you.... So, what's up?\n",
#  "Oh, like I wasn't dreading tomorrow enough, having to give it back to him... 'Hi Barry! Remember me? I'm the girl in the veil who stomped on your heart in front of your entire family!' Oh God and now I'm gonna have to return the ring, without the ring, which makes it so much harder...\n",
#  'Based on this play? ...Based on this play!\n',
#  "Well... I'm helping out down at the N.Y.U. Med School with some... research.\n",
#  'No? What happened, big guy?\n',
#  'Hey.\n',
#  'Oh, that is so sweet. (Touched, she puts an arm around her friend and kisses her.) Oh gosh, love you. Insurance?\n',
#  "(flailing arms in protest) Oh, hey hey hey, ho ho ho, hello, guy who doesn't want to know, standing right here!\n",
#  '(singing) Love is sweet as summer showers, love is a wondrous work of art, but your love oh your love, your love...is like a giant pigeon...crapping on my heart.  La-la-la-la-la- (some guy gives her some change and to that guy) Thank you. (sings) La-la-la-la...ohhh!\n',
#  "But I haven't used my card in weeks!\n",
#  'Are there no conscious men in the city for you two?\n',
#  'You cuddled.\n',
#  "I'm fine.\n",
#  'Who?\n',
#  '(pause)...Yeah. Yeah, I do.\n',
#  'Was there...uh, huh, huh, huh... andybody, anybody else there.\n',
#  'Ross.\n',
#  'OK, then get me your purse.\n',
#  'You know, if you tilt your head to the left, and relax your eyes, it kinda looks like an old potato.\n',
#  "I'm sorry, you know, maybe I wasn't being clear. Uh, this is our cart.\n",
#  'Would you excuse me for a second?\n',
#  "I guess you don't.\n",
#  '(singing) Love is sweet as summer showers, love is a wondrous work of art, but your love oh your love, your love...is like a giant pigeon...crapping on my heart.  La-la-la-la-la- (some guy gives her some change and to that guy) Thank you. (sings) La-la-la-la...ohhh!\n',
#  "Ooh! Ooh! And I brought Operation! But, um, I lost the tweezers, so we can't operate. But we can prep the guy!\n",
#  'By all means.\n',
#  'Oh, it is.\n',
#  'I just wish there was something we could do. (Bends down and talks to him) Hello. Hello, Coma Guy. GET UP, YOU GIRL SCOUT! UP! UP! UP!\n',
#  'Well, he made a move on me.\n',
#  "No, no. Uh... no, see, uh, you-you can't do that.\n",
#  "They wanna know if I'm okay. Okay.. they wanna know if I'm okay, okay, let's see. Well, let's see, the FICA guys took all my money, everyone I know is either getting married, or getting promoted, or getting pregnant, and I'm getting coffee! And it's not even for me! So if that sounds like I'm okay, okay, then you can tell them I'm okay, okay?\n",
#  'Ohhhh (Hugs her and sighs)\n',
#  'Did you call the cops?\n',
#  "I don't get it, I mean, you just got him. How can he be an adult already?\n",
#  'Mm.\n',
#  "C'mon, she's your mom!\n",
#  "(pauses) I'm pretty sure that it is...\n",
#  'Done.\n',
#  "Eww, I don't wanna do that.\n",
#  "Who's this from?\n",
#  "I'm still on my first. I just think you're nice.\n",
#  "Hey, hey, hey, that's not the rule and you know it.\n",
#  "Phoebe, you're gonna be with your grandma?\n",
#  'I know.\n',
#  '(hesitates) Are you sure?\n',
#  "Exactly. Weekend At Bernie's! Dead guy getting hit in the groin twenty, thirty times! No?\n",
#  "I don't know! Why don't you just explain? What do they want? Find out what they want!\n",
#  'Alright, check.\n',
#  'Ok, have a good break-up.\n',
#  'Ahhhh!\n',
#  '(as Monica) Hi, remember us?\n',
#  "(on phone) Hello?(Listens) Mindy! Hi! Hey, how are you? (Listens) Yes, yes, I've heard, congratulations, that is so great. (Listens) Really? (Listens) Oh. (Listens) Okay. Okay, well I'm working tomorrow, but if you want you can, you can, you can come by and... (Listens) Okay... (Listens) Great... (Listens) Great... (Listens) All right, so I'll, so I'll see you tomorrow! (Listens) Okay.. (Listens) Okay... (Listens) Bye. (Hangs up and sits down heavily.) Oh God. Oh God. Oh God.\n",
#  "What's goin' on?\n",
#  "I-I'm, I'm having a boy?\n",
#  'Which what?\n',
#  'You think?\n',
#  "Hello? Oh, uh, Rachel, it's the Visa card people.\n",
#  'OK.\n',
#  "Okay, alright, you buy me a soda, and then we're even. Okay?\n",
#  'Hey!\n',
#  'Oh, I cursed it. So now bad things will happen to he who spends it.\n',
#  'Hey, Janice.\n',
#  'The Luisa from home room!\n',
#  "Look, I don't even know how I feel about him yet. Just give me a chance to figure that out.\n",
#  'Oh, have either one of you guys ever been to the Rainbow Room? Is it real expensive?\n',
#  'Anyway, um, (Gets the ring out of her purse.) I guess this belongs to you. And thank you for giving it to me.\n',
#  "Ethan, it's um... it's icky.\n",
#  'What?\n',
#  'Whose little ball of paper is this?!\n',
#  "Oh! Man, I never thought I'd be here.. (She leans back onto his hand.)\n",
#  "(looking) Nono, that would be me again. I'm, uh, just trying something.\n",
#  'Marcel?!\n',
#  'Marcel! Where are you going with that disc?\n',
#  "Really? He does? (taking the phone) Hey, buddy, what's up! Oh, she told you about that, huh. Well, yeah, I have one now and then. Well, yeah, now. Well, it's not that big- ..well, that's true,.. Gee, y'know, no-one- no-one's ever put it like that before. Well, okay, thanks! (He hands the phone back and stubs out his cigarette.)\n",
#  "I'd just like to say that I'm totally behind this experiment. In fact, I'd very much like to butter your head.\n",
#  'Phoebe, what is it?\n',
#  "Big Bird's friend.\n",
#  'Alright, now try taking a puff.\n',
#  "Oh! Man, I never thought I'd be here.. (She leans back onto his hand.)\n",
#  "Look, you'll get there. You're an amazing chef.\n",
#  '...What did I ask?\n',
#  'Then she came back with "The question is, when are you gonna grow up and realise I have a bomb?"\n',
#  "No, I know. That's a part of the whole, you know, them-not-liking-you-extravaganza.\n",
#  "Ooh, oh, I've gotta go. (raises) Whoa, oh, head rush. One more, and then I have to go. (sits down, and then raises again) Cool!\n",
#  'Ah!\n',
#  'Are you okay?\n',
#  "(entering) Hey, you know our phone's not working?\n",
#  'Come here. (he hugs Rachel) Listen, you deserve so much better than him...you know, I mean, you, you, you should be with a guy who knows what he has when he has you.\n',
#  "All right, c'mere, gimme your feet. (She starts massaging them.)\n",
#  "All right, well, you're right, these are the best oatmeal cookies I've ever had.\n",
#  "Thanks, Phoebe. But I just don't really see myself in a big white hat.\n",
#  "(brings a plate of tiny appetizers over) Here you go, maybe this'll cheer you up.\n",
#  'I know.\n',
#  '(to Steve) This is Rachel.\n',
#  "(chuckles nervously) The sex? (chuckles) Um, I'm having enough trouble with the image of you and Susan together, when you throw in Tanya (miming washing hair, that's the best I could think of), yaw...\n",
#  "Yeah. Thought I'd give it a shot. I'm still on the first chapter. Now, do you think his 'love stick can be liberated from its denim prison'?\n",
#  "Man, hell of a two weeks, huh? Y'know what, though? I really feel like I learned something.\n",
#  'Yeah, yeah.\n',
#  "Well, 'cause then they'd be like my mom used to make them, you know, before she died.\n",
#  "That's nice. Get out Let's go, come on.\n",
#  "Hey, that woman's got an ass like Carol's! (They turn to stare at him.) What? Thought we were trying to find stuff.\n",
#  'What the hell are you doing? You scared the crap outta me.\n',
#  'Hello.\n',
#  "Marcel, I'm hungry.\n",
#  'Yeah.\n',
#  'See your twenty-five...and...uh, Monica, get my purse.\n',
#  'Thanks.\n',
#  '(grabs the bill) Give me that!\n',
#  "C'mon, you're going out with the guy! There's gotta be something wrong with him!\n",
#  "You- uh- y'know what, I'm gonna go. I don't- I don't think I can be involved in this particular thing right now.\n",
#  'That was not an incident! I-I was gesturing, a-and the plate slipped out of my hand.\n',
#  'Err, right.\n',
#  "Oh, just, y'know.... science.\n",
#  'Yeah, listen. Okay, before you do anything Joey-like, you might wanna run it by err... (he indicates Phoebe, who is helping Ross understand the remote control.)\n',
#  "No, I'm fine.\n",
#  'Hey.\n',
#  "And I hope Barry doesn't kill you and eat you in Aruba.\n",
#  '(as Ursula) If it was, would you stop hanging out with her?\n',
#  "I can't believe it. Paolo kissed my mom?\n",
#  '(out loud): We have apple cinnamon...\n',
#  'And everybody knows this?\n',
#  'So, um, did she...\n',
#  'Oh...\n',
#  'Is there? Is there someone else?\n',
#  "Oh, God, he's such a pig,\n",
#  'Hi, Paul, is it?\n',
#  "Where the hell've you been?\n",
#  'No.\n',
#  "What future boyfriends? Nono, I th- I think this could be, y'know, it.\n",
#  'Good for you. (jumps suddenly) Uh, quarters or rolls of quarters?\n',
#  'Yeah.\n',
#  'And I assume, Chandler, you are still boycotting all the pilgrim holidays.\n',
#  "Why not? Come on! Just, just close your eyes and tell me what you'd like to be doing right now.\n",
#  "I don't know. It's just not the same without Mom in the kitchen.\n",
#  'Oh, poor little Tooty is scared to death. We should find his owner.\n',
#  '(angry) Joey!\n',
#  'Nothing, just your overcoat sounds remarkably like Brent Mussberger.\n',
#  '(holding a card and waving it in front of her face) Hey you guys, look, the one-eyed jack follows me wherever I go. (they look at her) Right, OK, serious poker.\n',
#  "Marsha, these are cave people. Okay? They have issues like 'Gee, that glacier's getting kinda close.' See?\n",
#  'What? (the cat jumps on his shoulders) Ow!\n',
#  "No way! Mr.Salty is a sailor, all right, he's got to be, like, thetoughest snack there is.\n",
#  "What are you talking about? 'One woman'? That's like saying there's only one flavor of ice cream for you. Lemme tell you something, Ross. There's lots of flavors out there. There's Rocky Road, and Cookie Dough, and Bing! Cherry Vanilla. You could get 'em with Jimmies, or nuts, or whipped cream! This is the best thing that ever happened to you! You got married, you were, like, what, eight? Welcome back to the world! Grab a spoon!\n",
#  "(looking) Nono, that would be me again. I'm, uh, just trying something.\n",
#  'Me too.\n',
#  'Really?\n',
#  'Off to see young Ethan?\n',
#  "Hey, we all had better plans. This was nobody's first choice.\n",
#  'Outside.\n',
#  '(on phone) Daddy... Daddy... Daddy, why whyyy would I sleep with Billy Dreskin? His father tried to put you out of business! (Rachel turns to Monica, clasping the receiver to her bosom so Dr.Green can\'t hear, while mouthing "You are...") ...dead!\n',
#  "So Rachel, what're you, uh... what're you up to tonight?\n",
#  "No, no, no... why, because it might get weird for everyone else? Who cares about them. This is about us. Look, I-I've been in love with you since, like, the ninth grade.\n",
#  'Ooh, you guys have to make a wish.\n',
#  'Yeah, she said you looked like Ingrid Bergman that day.\n',
#  'Alright... (shuffles cards expertly, all the guys stare in amazement)\n',
#  "Why? Because everything is my responsibility? Isn't it enough that I'm making Thanksgiving dinner for everyone? You know, everyone wants a different kind of potatoes, so I'm making different kinds of potatoes. Does anybody care what kind of potatoes I want? Nooooo, no, no! (starting to cry) Just as long as Phoebe gets her peas and onions, and Mario gets his tots, and it's my first Thanksgiving, and it's all burned, and, and I... I...\n",
#  '(sarcastic) Oh. That WENUS.\n',
#  'Is he not cute enough for you?\n',
#  "(to Rachel) What's the matter? Why so scrunchy?\n",
#  "No!! Okay?! Why does everyone keep fixating on that? She didn't know, how should I know?\n",
#  'What, Ethan? He got to spend the whole day with you!\n',
#  "Come on. These people'll scooch down. You guys'll scooch, won't you? Let's try scooching! Come on. Come on. Uh, Kristen Riggs, this is Carol Willick. Carol, Kristin. Uh, Carol teaches sixth grade. And, Kristin, Kristin...(struggling)...does something that, funnily enough, wasn't even her major!\n",
#  "Ok, Monica, only dogs can hear you now, so, look, the door's open. Here we go.\n",
#  'Yeah, see.. you took mine. Chandler, what about you?\n',
#  "Well, it's like, last night, I couldn't do the thing that usually makes me great. So I had to do all this other stuff. And the response I got... man, oh man, it was like a ticker tape parade!\n",
#  'Every day is Lesbian Lover Day.\n',
#  'What?\n',
#  'Alright, Cincinnati, no blinds, everybody ante. (deals cards)\n',
#  'What?!\n',
#  'I thought that was just a rumour.\n',
#  "I don't know. I don't know... I thought about it all the way there, and I thought about it all the way back... and, uh, oh, you guys, y'know, it's Ross. Y'know what I mean? I mean, it's Ross.\n",
#  'Ross!\n',
#  '-leg?\n',
#  'Remember when we went to Central Park and rented boats?.. That was fun.\n',
#  "...Well, y'know, part of me wants that, but it's like I'm two guys, y'know? I mean, one guy's going 'Shut up! This is great!' But there's this other guy. Actually it's the same guy that wells up every time that Grinch's heart grows three sizes and breaks that measuring device... And he's saying, y'know, 'This is too hard! Get out! Get out!'\n",
#  'Oh my God..\n',
#  'Yeah, save it for the cab, okay.\n',
#  'Look at you! How, how do you feel?\n',
#  "Can't do it, can you?\n",
#  "(pulls his hand away) Okay! Okay. (To his parents) Look, I, uh- I realise you guys have been wondering what exactly happened between Carol and me, and, so, well, here's the deal. Carol's a lesbian. She's living with a woman named Susan. She's pregnant with my child, and she and Susan are going to raise the baby.\n",
#  "The hell with hockey, let's all do that!\n",
#  'Remembered what?\n',
#  'Myyy mother, ladies and gentlemen.\n',
#  "'Tonight' tonight?\n",
#  "Ben, Ben, hey Ben. Nothing. I don't think that's his name.\n",
#  'We have got to start locking that door!\n',
#  '(pointing at the drawing, upset) Bye... bye... BIRDIE.\n',
#  'OK. (Ross goes out on the balcony to talk to Rachel)\n',
#  'Oh my god, oh, you guys are great.\n',
#  "Yeah, well, you wouldn't think it was cool if you're eleven years old and all your friends are passing around page 79 of 'Mistress Bitch.'\n",
#  "(entering) How's it going?\n",
#  'No, nothing like that. I was just...such a dummie. I taught this "massage-yourself-at-home-workshop." And they are.\n',
#  'Saw what?\n',
#  'Yes, yes!\n',
#  'Huh.\n',
#  "Some days it's all I can think about.\n",
#  "(To Ross) I can't believe this! What the hell were you thinking?\n",
#  "It's great. Maybe tomorrow we can rent a car and run over some puppies.\n",
#  'Alright, Cincinnati, no blinds, everybody ante. (deals cards)\n',
#  '(leaving to serve others) Good for me!\n',
#  'Well, no, although I did have an imaginary friend, who... my parents actually preferred.\n',
#  'Because!\n',
#  "Okay, okay, what's going on?\n",
#  'Good for you, Joey.\n',
#  "Yeah, I mean... I think when it's your shot, y'know, you-you know it's your shot. Did it... feel like your shot..?\n",
#  'Alright, whadyou do with him?\n',
#  'Oh, how’d she take it?\n',
#  'Ooh! Bath salts would be nice.\n',
#  "(upset) Oh my Goood! Oh, do you think it's on all of them?\n",
#  '(to Ross): I thought we had them!\n',
#  'OK... see your two... and I raise you twenty. (throws it in)\n',
#  'Okay.\n',
#  "Oh, that's nice!\n",
#  "Okay. (They split it.) You know you probably didn't know this, but back in high school, I had a, um, major crush on you.\n",
#  'Yes, and I get my ya-yas from Ikea. You have to put them together yourself, but they cost a little less.\n',
#  'Yes have you seen any?\n',
#  'What, Phoebe, did you whip the potatoes? Ross needs lumps!\n',
#  'Oh, come on. What was with that whole Black Bart speech? (mimicking): "When I play poker, I\'m not a nice guy!"\n',
#  "During a blackout? He'd get trampled!\n",
#  "C'mon! C'mon!\n",
#  "Or, or, y'know, um, 'I think we should see other people' means 'Ha, ha, I already am'.\n",
#  "(Hushes her) Alright, great. Thanks a lot. (Hangs up) I'm going to tap class.\n",
#  "You know, I don't get this. A month ago, these people were my friends. You know, just because I'm in charge doesn't mean I'm a different person.\n",
#  'We checked. A lot.\n',
#  '(panicked) The oven is on.\n',
#  "Oh, well... 'cause.... you just... I don't like this question.\n",
#  'Good luck, man. I hope you get it.\n',
#  'Check.\n',
#  'Oh, OK.\n',
#  'Uh-uh. See, I see.... big passion in your future.\n',
#  "It's fine, it's fine. Look, do you wanna get this part, or not? Here.\n",
#  'Hey!\n',
#  "No it's not. It's small. It's tiny. It's petite. It's wee.\n",
#  "That's because I'm in front of them.\n",
#  "Okay, everybody relax. This is not even a date. It's just two people going out to dinner and- not having sex.\n",
#  "I am so sick of guys. I don't want to look at another guy, I don't want to think about another guy, I don't even want to be near another guy. (Ross crosses arms)\n",
#  "I know. It's just such reckless spending.\n",
#  "So how's it going there in Financial Services?\n",
#  'Oh, not much. I-I got a job.\n',
#  '(to Ross) "Big guy?"\n',
#  "What, it's ok when Chandler does it?\n",
#  'Hello? Like he was really gonna send you one? (To Phoebe) She was a big girl.\n',
#  "Oh, Satan's minions at work again...\n",
#  "It's supposed to be that small. It's a pre-appetizer. The French call it an amouz-bouche.\n",
#  "So I have a flaw! Big deal! Like Joey's constant knuckle-cracking isn't annoying? And Ross, with his over-pronouncing every single word? And Monica, with that snort when she laughs? I mean, what the hell is that thing? ...I accept all those flaws, why can't you accept me for this?\n",
#  '...little playthings with yarn?\n',
#  'Where are you guys going? Come on, one more game!\n',
#  "So Rachel, what're you, uh... what're you up to tonight?\n",
#  "Aw, don't do that\n",
#  "Bullwinkle socks. That's so sweet.\n",
#  "What does that mean?   Does he sell it, drink it, or just complain a lot? (Chandler doesn't know.)\n",
#  "That's because as far as my parents are concerned, Ross can do no wrong. Y'see, he's the Prince. Apparently they had some big ceremony before I was born.\n",
#  'My god, Angela.\n',
#  "You are? Ross, I'm sorry..\n",
#  "Look, Rachel, this is poker. I play to win, alright? In order for me to win, other people have to lose. So if you're gonna play poker with me, don't expect me to be a 'nice guy,' OK? Cause once those cards are dealt... (claps hands three times)\n",
#  "(on phone) Excuse me. (covers up phone; to Ross) It's about the job.\n",
#  'Excuse me?!\n',
#  'Just...please tell him.\n',
#  '(ducking) Get down!\n',
#  'I am not wrong.\n',
#  "I couldn't be inner. Monica?\n",
#  'OK.\n',
#  "Her name is Celia. She's not a bug lady. She's curator of insects at the museum.\n",
#  'Good luck.\n',
#  'Chandler, will you just come in already?\n',
#  "You're good.\n",
#  'I don\'t know, birds just don\'t say, "Hello, sit here, eat something."\n',
#  "I said that you had a nice butt, it's just not a great butt.\n",
#  "Wait, did you get to the part about his 'huge throbbing pens'? Tell ya, you don't wanna be around when he starts writing with those!\n",
#  "Hey. How did, uh, how'd it go today?\n",
#  "Look Daddy, it's my life. Well maybe I'll just stay here with Monica.\n",
#  '(to Joey) One more game?\n',
#  'Oh, Monica! Would you stop being such a wuss?\n',
#  'Urse...\n',
#  "(on phone) Yeah, you want 55-JUMBO. Yeah, that's right. That's right, JUMBO with a U, sir. (pause) No, belive me, you don't want me. Judging by his number, I'd be a huge disappointment. (pause) All rightie, bye bye.\n",
#  'Thank you. Thank you so much!\n',
#  'Oh. Then, no.\n',
#  "Yeah. We don't speak. She's like this high-powered, driven career type.\n",
#  'Oh. What?\n',
#  'Was that the cake?\n',
#  'I’ll get it.\n',
#  'Ok, you can not do this to me.\n',
#  "Something went wrong with Underdog, and they couldn't get his head to inflate. So anyway, um, his head is like flopping down Broadway, right, and I'm just thinking... how inappropriate this is. Um, I've got something in my eye, uh, Joey, could we check it in the light, please?\n",
#  'I just feel like someone reached down my throat, grabbed my small intestine, pulled it out of my mouth and tied it around my neck...\n',
#  '(entering quietly) Hey.\n',
#  'Whaddya see?\n',
#  "Hey, you.... So, what's up?\n",
#  'Oh, okay. Send her in.\n',
#  "So you're free Thursday, then.\n",
#  'Oh, ok bye-bye.\n',
#  "Y'know, I know it's totally superficial and we have absolutely nothing in common, and we don't even speak the same language but Goooooooddddddd....\n",
#  '(as Rachel) Hi.\n',
#  'Need a new table.\n',
#  'Show them to me!\n',
#  'Do you really want a job with Popular Mechanics?\n',
#  'Oh, yeah, check it. Definitely, I want some of that.\n',
#  "Hi, uh, I'll be reading for the role of Mercutio.\n",
#  "Bob? Who the hell's Bob?\n",
#  'Change!  Okay, sit down. (Shows Paul in) Two seconds.\n',
#  'Oh... Oh, Pheebs.\n',
#  "(clutching a beer can and sniffing) This was Carol's favorite beer. She always drank it out of the can, I should have known.\n",
#  'Yes! And that would be a shut-down!\n',
#  'I have no idea.\n',
#  'Oh, I uh, just came by to pick up my skull. Well, not mine, but...Susan: Come in.\n',
#  'Yeah. Cushions the blow.\n',
#  'Thank y... (thinks about it)\n',
#  '(to Phoebe) Would you stop?\n',
#  "Oh, Joey, please tell me you're only donating your time.\n",
#  'Oh, how’d she take it?\n',
#  "Oh, she wants to see me tomorrow...Oh, she sounded really weird, I gotta call Barry... (Does so, on phone) Hi, it's me, I just.. Mindy!! Mindy! Hi! No, I figured that's where you'd be!\n",
#  "Ok, I'm off to talk to my unborn child.\n",
#  "That's so funny, 'cause I was thinking you look more like Joey Tribbiani, man slash woman.\n",
#  '(triumphantly) The Unbearable Likeness of Being!\n',
#  'Yeah, but did they have to shoot him down? I mean, that was just mean.\n',
#  "Wha, heh, how could you know, I don't even know!\n",
#  'No, no, Dad, I was just wondering.\n',
#  'Hey, hey, hey, hey, quit making up rules!\n',
#  'Last time I do that, I promise.\n',
#  "No, it doesn't, does it? But you wanted lumps, Ross? (picks up the pan of badly burnt potatoes) Well, here you go, buddy, ya got one.\n",
#  "What's up man?\n",
#  'No, you?\n',
#  "Yeah, I know, he's sweet, but it's just not fun anymore, you know? I don't know if it's me, or his hunger strike, or, I don't know.\n",
#  'And this from the cry-for-help department. Are you wearing makeup?\n',
#  "It's just a fur ball.\n",
#  '(innocently) What?\n',
#  "Well, go over to her! She's not with anyone.\n",
#  'Guys! Guess what, guess what, guess what, guess what!\n',
#  'Hey, Pheebs.\n',
#  'Yes, every single one of them.\n',
#  "Uh, nothing, I'm sure they'll be impressed with your excellent compuper skills.\n",
#  'Marcel?\n',
#  'She is unbelievable, our mother is...\n',
#  'No I didn\'t. I asked, "got the ke-eys?"\n',
#  "Hey, you guys in the living room all know what you want to do. You know, you have goals. You have dreams. I don't have a dream.\n",
#  'She lent me an egg once.\n',
#  "Oh, it's okay, it was just my left leg.\n",
#  "(getting up, upset) I'm calling Mom.\n",
#  "I'm outta here. Here's my credit card. Dinner's on me. I'm sorry, Chandler.\n",
#  'Petrie.\n',
#  "Alright, well, I'm gonna order a pizza. (gets up)\n",
#  'No, nothing like that. I was just...such a dummie. I taught this "massage-yourself-at-home-workshop." And they are.\n',
#  'Come on, you made coffee!   You can do anything! (Chandler slowly tries to hide the now dead plant from that morning when he and Joey poured their coffee into it.)\n',
#  "Oh, now, don't listen to him, Pheebs, I think it's endearing.\n",
#  'Which, by the way, is the real San Francisco treat. (Calls her, then hurriedly hangs up.) I got her machine.\n',
#  "Janice. Hi, Janice. Ok, here we go. I don't think we should go out anymore. Janice.\n",
#  "Yeah! You know all those yummy noises? I wasn't faking.\n",
#  "Hey Ross. This probably isn't the best time to bring it up, but you have to throw a party for Monica.\n",
#  "Oh, look, he's closing his eyes again.\n",
#  "Yeah, well, I only have twenty minutes until Ethan, so, y'know.. (He starts to raid the fridge.)\n",
#  '(proud) I know, but, I made a huge mistake. I never should have broken up with her. Will you help me? Please?\n',
#  'No, give me the...\n',
#  '(into phone) Pants and a sweater? Why, mom? Who am I gonna meet in a blackout? Power company guys? Eligible looters? Could we talk about this later? OK. (hangs up)\n',
#  'Does anyone want the rest of this Pop-Tart?\n',
#  'Ok, yeah, ok. (she throws the directions in) Oh, OK.\n',
#  "Come on, come on. Damnit, damnit, damnit, damnit. (to Susan) This is all your fault. This is supposed to be, like, the greatest day of my life, y'know? My son is being born, and I should be in there, you know, instead of stuck in a closet with you.\n",
#  "You're wrong.\n",
#  'Here goes. (He walks over to her but just stands there.)\n',
#  "Thanks. Hi, um, 'kay. I'd like to start with a song that's about a man that I recently met, who's, um, come to be very important to me. (Monica gives her a look) 'Kay. (Sung:)\n",
#  'Well, isn’t, isn’t that gonna be weird?\n',
#  "(on phone) Could you please tell me what this is in reference to? (Listens) Yes, hold on. (To Rachel) Um, they say there's been some unusual activity on your account.\n",
#  'I wish all guys could be like him.\n',
#  'What?\n',
#  'I gave you one job! (Starts to examin the lasagne through the bottom of the glass pan.)\n',
#  "Wo-wo-whoa. What about Phoebe's birthday?\n",
#  'Sure, why not?\n',
#  'Why not?\n',
#  'I know, I still am one of these.\n',
#  'Ok, right about now the turkey should be crispy on the outside, juicy on the inside. Why are we standing here?\n',
#  "Oh, okay, I don't know what you just said, so let's get started.\n",
#  'Yeah? What does she think of your little science project?\n',
#  "Rachel, there's nothing in it.\n",
#  "This Alan again? How's it goin'?\n",
#  'We, we come back from our walk and the- the phone was ringing...\n',
#  "Oh, I was hoping you wouldn't remember.\n",
#  'They’re twins!\n',
#  'And Monica knows...\n',
#  'Oh no, you see, actually it is.\n',
#  "What's going on here? You go out with tons of girls.\n",
#  "Oh, OK, so then what is it? Some kind of... you know, like, like... some kind of, y'know, like... alright, what is it?\n",
#  'Really?\n',
#  'Unless...\n',
#  "Oh, that's fine, no.\n",
#  "Uh...no. No, no, in fact, you're not having a boy.\n",
#  '(overhearing) What kind of research?\n',
#  "(squatting and reading the instructions) I'm supposed to attach a brackety thing to the side things, using a bunch of these little worm guys. I have no brackety thing, I see no whim guys whatsoever and- I cannot feel my legs.\n",
#  'Guys! Guess what, guess what, guess what, guess what!\n',
#  'Monica, would you calm down? The credit card people said that you only have to pay for the stuff that you bought.\n',
#  'Oh, no, no. Nina... (miming fairies twinkling around his head) ..she is whooo wewee-woo whoo whoo! In fact, if you asked her right now, she would have no recollection of being fired at all, none at all.\n',
#  "Oh, Satan's minions at work again...\n",
#  'You are not putting that on again! Marcel, OK—if you press that button, you are in very, very big trouble.\n',
#  "Yeah, at Macy's. You were the Obsession girl, right? I was the Aramis guy. (pretends to spray cologne) Aramis? Aramis?\n",
#  'Oh, I wanna see! Lemme see! Lemme see! (She runs up and takes the binoculars.)\n',
#  'I know this is going to sound unbelievably selfish, but, were you planning on bringing up the whole baby/lesbian thing? Because I think it might take some of the heat off me.\n',
#  "Okay. It's-it's about Alan. There's something that you should know. I mean, there's really no easy way to say this.. uh.. I've decided to break up with Alan.\n",
#  "Hell no, we'll pay!\n",
#  'Why not?\n',
#  'Oh.. a little..\n',
#  'I remember the day I got my first pay check. There was a cave in in one of the mines, and eight people were killed.\n',
#  "Yeah. I'm thinking, if we put our heads together, between the two of us, we can break them up.\n",
#  'What does she mean?\n',
#  'Yes.\n',
#  'Oh, please, that is such a lame excuse!\n',
#  'Ha, I made you look....\n',
#  'Why?! Why? Why, why would anybody do something like that?\n',
#  "Oh, so what you're saying is you're not completely fulfilled by Rick, Ethan and myself?\n",
#  "Okay, umm-umm, I'll just--I'll be right back, I just gotta go ah, go ah...\n",
#  'No, I just talked to them.\n',
#  'And then, like three days in a row he got to the newspaper before I did, and peed all over the crossword.\n',
#  'I need some milk.\n',
#  "You're not a senior?\n",
#  'That oughta do it.\n',
#  'I, er...\n',
#  'Well, I never call me.\n',
#  'I got it.\n',
#  'We all chipped in.\n',
#  "Don't you have a laundry room in your building?\n",
#  'Then why the hell are you dumping my brother?!?\n',
#  '(as Monica) And by the way, have I mentioned that back in high school, I was a cow?\n',
#  "I just wan't to...\n",
#  "Man, hell of a two weeks, huh? Y'know what, though? I really feel like I learned something.\n",
#  "And here we have the last of Paulo's grappa.\n",
#  "When's that?\n",
#  'Where have you been?\n',
#  "I don't know. You dumped her on New Year's.\n",
#  "I-I'm, I'm having a boy?\n",
#  'So.... I quit.\n',
#  "I don't know. We're talking about whipped fish, Monica. I'm just happy I'm keeping it down, y'know?\n",
#  "Hello? (Listens) Um, yeah, uh, (snapping her fingers at Ross who takes the remote from Marcel, then turns off the TV) Okay ah, hold on a second, lemme lemme just check and see if see if she's here.\n",
#  "Shh! (singing) Here we come, walkin' down the street, get the funniest looks from, everyone we meet. Hey, hey! (to Carol) Hey, uh, did you just feel that?\n",
#  "Ok. (browsing the apartment) Wow, you guys sure have a lot of books about bein' a lesbian.\n",
#  'Hey.\n',
#  "All right, fine. Tonight's potatoes will be both mashed with lumps, and in the form of tots.\n",
#  "(in baby-like voice) How come you don't live with Mommy? (pause; shows Ross less than amused) How come Mommy lives with that other lady? (pause; Ross still looks less than amused; Joey smiling) What's a lesbian? (playfully hits Ross)\n",
#  'That sounds like Nana.\n',
#  "And you've got lenses! But you hate sticking your finger in your eye!\n",
#  '(Looking out at the balcony) So tell me something, is leaving the Christmas lights up part of your plan to keep us merry all year long?\n',
#  "Hey, look, we're on that TV thing!\n",
#  "Well maybe it's cold in there. Or maybe I screwed up the first date I had in 9 years.\n",
#  '(entering with Paolo, arm in arm) Everybody, this is Paolo. Paolo, I want you to meet my friends. This is Monica.\n',
#  'And (he imitates the buzzer) to you too, Helen.\n',
#  'How many you want?\n',
#  "Okay, but Pheebs, Pheebs, Jack gave up a cow, I gave up an orthodontist. Okay, I-I-I know, I know I didn't love him-\n",
#  "Who cares, we'll eat at the sink! Come on, let's play!\n",
#  'Yes.\n',
#  "He doesn't have anyone.\n",
#  'Joey ate my last stick of gum, so I killed him. Do you think that was wrong?\n',
#  "Well, I just lost a job, and I'd like to raise the bet five bucks. Does anybody have a problem with that?\n",
#  '(gets up) OK, how does everybody like their burgers?\n',
#  'I’m sayin’ I see a difference.\n',
#  "No you don't.\n",
#  'Heh... I was bluffing.\n',
#  '(smiling)....with??\n',
#  'No.\n',
#  "(finishing changing Chandler's nicotine patch) There y'go.\n",
#  'We forgot to sign one of the admissions forms.\n',
#  "Uh, it's 2:30 in the morning!\n",
#  'What... I could, I could do it. What is it?\n',
#  "Alright. There's a theory, put forth by Richard Leakey-\n",
#  "(with a deep voice) Mr. Bing's office. (Listens) No I'm sorry, he's in a meeting right now.\n",
#  'Hi Pheebs!\n',
#  'Set another place for Thanksgiving. My entire family thinks I have VD.\n',
#  "You can see where he'd have trouble.\n",
#  "Here's a little tip, she really likes it when you rub her neck in the same spot over and over and over again until it starts to get a little red.\n",
#  "Rach, here's your mail.\n",
#  'Oh, OK.\n',
#  'Hell is filled with people like you.\n',
#  "Relax. You're only at nine centimeters. And the baby's at zero station.\n",
#  'What is this?!\n',
#  'Wh- are you welling up?\n',
#  'Look at that!\n',
#  "Uhhhh.... I'll just pee in the street.\n",
#  'No... no! And yet it did. Good-bye, Janice.\n',
#  "(Tiny laugh) yep, that's me, (tiny laugh) I am that stupid (tiny laugh).\n",
#  '(wiping his brow) Ah...ooh! Well, looks like, uh, we kicked your butts.\n',
#  'What?\n',
#  'Oh, well, ah... maybe that’s because they’re ah... jealous, of us.\n',
#  'Hi, Just Janice.\n',
#  'Why?\n',
#  'I’m gonna be a father.\n',
#  'Hey!\n',
#  'Shut up!\n',
#  '(to Ross) Let me get you some coffee.\n',
#  'Career counselor?\n',
#  "I don't know. It's just not the same without Mom in the kitchen.\n",
#  'Guess what?\n',
#  "Go Monana! Well, you ladies are not the only ones living the dream. I get to go pour coffee for people I don't know. Don't wait up. (Exits)\n",
#  'You guys okay?\n',
#  'Or?\n',
#  "You know, did you ride mopeds? 'Cause I've heard... (they stare at her)... oh, I see... it's not about that right now. OK.\n",
#  "I'm so sorry, I can't believe I did this, but I couldn't stop laughing at your Norman Mailer story.\n",
#  'Anybody wanna trade? Oh...\n',
#  "Well, we're applying to a lot of them. Naturally our first choice would be one of the bigger state zoos, y'know, like, uh, San Diego... right? But that might just be a pipe dream, because, y'know, he's out of state. Uh, my vet, uh, knows someone at Miami, so that's a possibility.\n",
#  '(Closing the door) Goodbye Mr.Heckles.\n',
#  'No. Oh, oh, I guess it would be different if I were- with somebody.\n',
#  'Mmmm.\n',
#  "Yeah, yeah, it's just that with my last roommate Kip...\n",
#  'Nah... not-not special enough.\n',
#  "(bursts out laughing again) I can't believe you didn't know it was a line!\n",
#  "Alright. (He goes to get the glasses. Then he hesitates and turns off the main light. Rachel looks round and he acts surprised) The, uh, the neighbours must be vacuuming. (He sits down and starts to pour the wine) Well, so long as we're here and, uh, not on the subject, I was thinking about, uh, how mad we got at each other before, and, um, I was thinking maybe it was partially because of how we, um...\n",
#  "It was unbelievable. I-I've never met anyone like her. She's had the most amazing life! She was in the Israeli army...\n",
#  "I can't remember the last time I got a girl to take care of my monkey.\n",
#  'Um you, you got a minute?\n',
#  "I honestly don't know if I'm hungry or horny.\n",
#  'Services? (Ross looks at him) Oh, services.\n',
#  'Hey, when did you and Susan meet Huey Lewis?\n',
#  "G'bye, Nana. (She kisses her on the forehead.)\n",
#  'You know what?\n',
#  '...I can imagine.\n',
#  'Okay..\n',
#  "(reading Monica's palm) No, 'cause this line is passion, and this is... just a line.\n",
#  "(sarcastically) And you didn't marry him because...?\n",
#  '(singing)\n',
#  "Let her know I like her? What are you, insane? (The girls make disgusted noises.) It's the next day! How needy do I want to seem? (To the guys) I'm right, right?\n",
#  '59 seconds. (holds up his watch) Quartz, ha.\n',
#  "Marcel is an illegal exotic animal. I'm not allowed to have him in the city. If they find him, they'll take him away from me.\n",
#  'The actress!\n',
#  'Ross, that’s my jacket.\n',
#  "I-I'm, I'm having a boy?\n",
#  'That is so sweet, you guys. (hugs them)\n',
#  'Relax your hand!\n',
#  "Burning's good. Yeah, I got stuff to burn.\n",
#  'Yeah, you too.\n',
#  'God, what a great day. ...What? Weather-wise!\n',
#  'Pete the Weeper? Remember that guy who used to cry every time we had sex. (imitating) "Was it good for you?"\n',
#  "This is so unfair! She's got everything I want, and she doesn't have my mother.\n",
#  "(hums for a while, then gives up, and in her head) If it bothers you that much, just go out and get the shoes. No. Don't do this. This is stupid! I don't have to prove anything, I'm gonna go get them...But then everyone will know. Unless I get them, and then wake up really early and put them back! ...I need help! (She buries her head in her pillow.)\n",
#  "Oh c'mon! When we were kids, yours was the only Raggedy Ann doll that wasn't raggedy!\n",
#  'Excuse me? Can I help you with anything?\n',
#  "We just finished this magnificent Thanksgiving dinner. I have--and I remember this part vividly--a mouthful of pumpkin pie, and this is the moment my parents choose to tell me they're getting divorced.\n",
#  'My God.\n',
#  '(answering phone) Hel-lo, Rachel Green.\n',
#  'Ok, ok, here we go. (he crouches down near her stomach) Ok, where am I talking to, here? I mean, uh, well, there is one way that seems to offer a certain acoustical advantage, but...\n',
#  'Oh. Hi, Mr.Heckles.\n',
#  'Uh, hi. We uh, we used to work together.\n',
#  'Yes, Bunny?\n',
#  "Um, oh, I've got a birthday party, with some work people.\n",
#  '(to Ross): Loser?\n',
#  'Then why the hell are you dumping my brother?!?\n',
#  'What?\n',
#  "C'mon, you can't live off your parents your whole life.\n",
#  "Ooh, ok, that's it. Enough with the keys. No one say keys.\n",
#  'Hi.\n',
#  'It is so great to meet a guy who is smart and funny, and has an emotional age beyond, like eight.\n',
#  'Sure, why not?\n',
#  'Here we go.\n',
#  'Lots of responses.\n',
#  'Well, is it, like, a little annoying, or is it like when Phoebe chews her hair?\n',
#  "You don't drink.\n",
#  'Well, we both have.\n',
#  'You still on that?\n',
#  'Aww. Thank you, Aunt Phoebe.\n',
#  'Well... of course I thought of you! But... but...\n',
#  'Sure.\n',
#  'Michael.\n',
#  'What?\n',
#  'No, why?\n',
#  'Could tonight be the Night?\n',
#  'So how are things going with you two? Is she becoming your (provocatively) special someone?\n',
#  "Well, my secretary is gonna be out for a couple of weeks. She is having one of her boobs redused. (Ross looks at her.) It's a whole big boob story.\n",
#  '...pig...pig man!\n',
#  'Waaay too special.\n',
#  '(grins and walks to the kitchen and says to Chandler and Joey.) I helped!\n',
#  'Pheebs, you remember how we talked about saying things quietly to yourself first?\n',
#  'Ow ow ow. Ow ow ow ow. Ow ow ow. Ow. Ow. Ow. Ow.\n',
#  "Whoah, boy, hockey was a big mistake! There was a whole bunch of stuff we could've done tonight!\n",
#  'Still, you- you say Minnie, you hear Mouse. Um, how about, um.. how about Julia?\n',
#  "Ok, ok, ok, ok, here goes. You know, I, you know, can't do this. Uh, this is too weird. I feel stupid.\n",
#  'A couple hours.\n',
#  "Yeah. It's Dutch.\n",
#  'You know, you and Bob, and me and my girlfriend, uh, uh, Monica.\n',
#  "What's goin' on?\n",
#  "I'm serious. You're amazing. You know when to spritz, when to lay back.\n",
#  "Would you let it go? It's not that big a deal.\n",
#  "So how does this work, you going to balance the plates on these little guys' heads?\n",
#  "Well, maybe that's my decision. Well, maybe I don't need your money. Wait!! Wait, I said maybe!!\n",
#  "Hi, um, I'm account number 7143457. And, uh, I don't know if you got any of that, but I would really like a copy of the tape.\n",
#  '(to Steve) This is Rachel.\n',
#  '(returns) Yeah, alright.\n',
#  'Breathe.\n',
#  'Why?\n',
#  'Which ones?\n',
#  'Funny, my birthday was seven months ago.\n',
#  'Okay, Pheebs, can I ask? So, he’s going out with her. I mean, is it really so terrible?\n',
#  "Ok, ok, ok, ok, here goes. You know, I, you know, can't do this. Uh, this is too weird. I feel stupid.\n",
#  'Wait, wait, wait!\n',
#  '...medium...hmm...any cookies left?\n',
#  'Okay, quick and painful. (Starts to cork the wine)\n',
#  "Me either... (He pulls up a stool so that he doesn't have to move his hand.)\n",
#  'Hey, I might!\n',
#  'Really? Just casually strewn about in that reckless haphazard manner?\n',
#  'Yeah, well, is that better?\n',
#  'Well, what happened?\n',
#  'I did.\n',
#  'Mindy?! My maid of honour, Mindy?!\n',
#  '(panicked) The oven is on.\n',
#  "Oh, hello, kettle? This is Monica. You're black.\n",
#  "..You're, you're 'mah mah mah' what?\n",
#  'What do you mean?\n',
#  'Oh, you must stop shooping.\n',
#  'Oh, big glamour night. Me and Monica at Laundorama.\n',
#  '(sticking her foot out) Hm-m.\n',
#  'I got you the foot massager.\n',
#  "You have to tell her! You have to tell her! It's your moral obligation, as a friend, as a woman, I think it's a feminist issue! Guys? Guys? (waiting for guys to chime in)\n",
#  'Wait here. Breathe.\n',
#  "'The hills were alive with the sound of music.'\n",
#  'Nuh-uh.\n',
#  "Yeah, I mean... I think when it's your shot, y'know, you-you know it's your shot. Did it... feel like your shot..?\n",
#  "She's living my life, and she's doing it better than me! Look at this, look. She buys tickets for plays that I wanna see. She, she buys clothes from stores that I'm intimidated by the sales people. She spent three hundred dollars on art supplies.\n",
#  "That's the rule.\n",
#  'Oh... (opens it)... (sees it is a pin) Oh my God. He remembered.\n',
#  "Well, let's just say the impressions you made in the butter left little to the imagination.\n",
#  "Sure, every time, you're such a princess...\n",
#  "How would I know? I-I wasn't here.\n",
#  'Um, is it sugarless?\n',
#  "I'm telling you, that monkey is a chick magnet! She's going to take one look at his furry, cute little face and it'll seal the deal.\n",
#  "Yeah, but did you see the dents in his knuckles? That means he's artistic.\n",
#  "Yeah, but you were the one who got him back, y'know? You, you were great. ...Hey, we uh, we still have that, uh, that bottle of wine. You in the mood for, uh, something grape?\n",
#  "All right, fine. Tonight's potatoes will be both mashed with lumps, and in the form of tots.\n",
#  'If you wanna put a label on it.\n',
#  'Monica, in or out?\n',
#  'Let’s not do that any more.\n',
#  '(Into mike) Okay, that was Phoebe Buffay, everybody. Woo!\n',
#  '...medium...hmm...any cookies left?\n',
#  'Why would I have the keys?\n',
#  'So.\n',
#  'Aw, right.\n',
#  'Hi.\n',
#  'You missed a belt loop.\n',
#  "I know, I just want to bite his bottom lip. (Rachel looks at her) But I won't.\n",
#  "No, no, no... why, because it might get weird for everyone else? Who cares about them. This is about us. Look, I-I've been in love with you since, like, the ninth grade.\n",
#  "Nononononono. Think who you're dealing with here. I mean, I'm not like you. I-I can't even stand in front of a tap class.\n",
#  "I'm trppd... in an ATM vstbl... wth Jll Gdcr!\n",
#  'Yeah, but did they have to shoot him down? I mean, that was just mean.\n',
#  "(from the air vent overhead) You guys, he's beautiful!\n",
# ...
#  'Oh.\n',
#  'Not from where I was standin’.\n',
#  'Marcel?\n',
#  'Well, you were pretty damn good.\n',
#  'Hi!\n',
#  '(reading): OK... Dear Ms. Green... yeah... yeah... yeah... No. (crumpes up letter)\n',
#  'All right, you guys, I kinda gotta clean up now. (They all start to leave.)\n',
#  "Um, I'm not actually Amish.\n",
#  '(weakly) No.\n',
#  'Monica? Monica!\n',
#  '(in disbelief) Vulva?\n',
#  'Come on, we were great together. And not just at the fun stuff, but like, talking too.\n',
#  'Ha. Ha, ha.\n',
#  "Who wasn't invited to the wedding.\n",
#  'Wow, being dumped by you obviously agrees with her.\n',
#  'Did not.\n',
#  'Huh.\n',
#  'I don’t care. Phoebe’s Phoebe. Ursula’s... hot!\n',
#  "'S'funny, um, uh, we agreed we'd spend the rest of our lives together. Things change, roll with the punches. I believe Julia's on the table..?\n",
#  "I don't know. Maybe I'll know when I see him.\n",
#  'That is so unfair!\n',
#  'Oh, yeah, yeah. Actually, I got the extended disco version, with three choruses of "You\'ll never make it on your own".\n',
#  "Wait—oh—hey—huh, oh great now he knows, and I don't know!\n",
#  "Great, now he's waving back.\n",
#  "Okay. Okay, we'll be here! Hating you! Did you see how he was sweating when he walked out of there? Listen honey, if I'm hogging the ball too much you just jump right in there and take a couple punches because I'm telling you, this feels great.\n",
#  'What?\n',
#  "(draws back) Really. Mindy, if it'll make you feel any better, when I was engaged to him he went through a whole weird thing too.\n",
#  "All right, kids, I gotta get to work. If I don't input those numbers,... it doesn't make much of a difference...\n",
#  'Pheebs, why would you want to operate a drill press?\n',
#  "I'm having a baby in here! Ok, everyone stand back. (Walks backwards as if he is going to break down the door, but steps in a bucket and falls) Ow.\n",
#  'Say it... say it!\n',
#  'Oh, okay. Will you take my place?\n',
#  'What?!\n',
#  'Oh yeah? And who do you like?\n',
#  "Man, if you tried something like that on my birthday, you'd be starin' at the business end of a hissy fit.\n",
#  'I love babies, with their little baby shoes, and their little baby toes, and their little baby hands...\n',
#  "Oh.. you don't get it! (Passes out and slumps across her)\n",
#  "No, no, no. They say it's the same as the distance from the tip of a guy's thumb to the tip of his index finger.\n",
#  'And I assume, Chandler, you are still boycotting all the pilgrim holidays.\n',
#  "I was really upset about Rachel and Paolo, and I think I had too much tequila, and Nora- um, Mrs. Mom- your Bing- was just being nice, y'know, and- But nothing happened, nothing- Ask Joey, Joey, uh, came in-\n",
#  'I see your twenty, raise you twenty-five. (throws it in)\n',
#  'I was laughing! You made me laugh! (Monica and Rachel start to squabble)\n',
#  'You-you had what?\n',
#  "I mean, why should I let them meet him? I mean, I bring a guy home, and within five minutes they're all over him. I mean, they're like- coyotes, picking off the weak members of the herd.\n",
#  'Thank you. (Examines it) Oh, cool! Free sample of coffee!\n',
#  "And, we're done with the yogurt. (Sets yogurt down on table)\n",
#  'Popes in a Volkswagen! ...I love that joke.\n',
#  "(points at Joey's pen) Uh, uh, gimme. Can you see me operating a drill press?\n",
#  'Yeah, get out!\n',
#  '(hurt) Waitressing?\n',
#  "Come on, you know, Thanksgiving. Ooh, you got the bigger half. What'd you wish for?\n",
#  'Okay, you guys spend waaaay too much time together. (Goes back inside and shuts the door)\n',
#  "You have to tell her! You have to tell her! It's your moral obligation, as a friend, as a woman, I think it's a feminist issue! Guys? Guys? (waiting for guys to chime in)\n",
#  "No, no. Uh... no, see, uh, you-you can't do that.\n",
#  "No, it's not just that. It's just—I want someone who... who does something for me, y'know? Who gets my heart pounding, who... who makes me, uh... (begins to stare lovingly at Rachel)\n",
#  'Huh.\n',
#  "(to Monica): Could you take it to Carol's every now and then, and show it to Ben, just so he doesn't forget me?\n",
#  'What was with the dishes?\n',
#  '(spitting out her drink in shock) Oh God, oh God, I am sorry... I am so sorry...\n',
#  "I- I think they're great! I, I really do.\n",
#  'Joey, please.\n',
#  'Why?\n',
#  'Look out, incoming pumpkin pie!\n',
#  'Hey, hey.\n',
#  'Hi, I thought you might like some ice chips.\n',
#  'Do it!\n',
#  "No, actually I was just saying it looks like we're not sitting together. But now you mention it, there was ice there that night... It was the first frost...\n",
#  'Last night.\n',
#  'You wanna watch Laverne y Shirley?\n',
#  'Well, what about Mindy?\n',
#  'Yeah\n',
#  'So, Saturday night, the big night, date night, Saturday night, Sat-ur-day night!\n',
#  'You be okay?\n',
#  "Joey, what's going on?\n",
#  'Oh, wow, so you\'re gonna be one of those "healthy, healthy, healthy guys"?\n',
#  'No, women are welcome to play.\n',
#  "Uh, I'm not really a shot drinking kinda guy.\n",
#  "How'd you know I was coming?\n",
#  'This is nice. We never do anything just the two of us.\n',
#  'Holden McGroin.\n',
#  'Don\'t stare. Now she just finished throwing his clothes off the balcony, now there\'s just a lot of gesturing and arm-waving, (shows Rachel gesturing with hands in front of her chest), Ok, that is either, "How could you?" or, "Enormous breasts!" Here he comes!\n',
#  "Ooh! That's so nice...\n",
#  "C'mon, you guys, it wasn't that bad. It was better than that thing I did with the trolls, at least you got to see my head.\n",
#  'Oh.... my God.\n',
#  'Big time!\n',
#  'What are you guys doing here?\n',
#  "There, well, see? Barry wouldn't even kiss me on a miniature golf course.\n",
#  "Y'think?\n",
#  'Do what, do what?\n',
#  'Hey.\n',
#  'Why would I tell him?\n',
#  "Hey, that's... that's 'joincidence' with a 'C'!\n",
#  'Can we come in?\n',
#  'I just never had a relationship with that kind of passion, you know, where you have to have somebody right there, in the middle of a theme park.\n',
#  'Hey, Phoebe, I asked you, and you said it was okay.\n',
#  'How-how are you, Mom?\n',
#  'Remembered what?\n',
#  'Ooh...hey honey, are you all right?\n',
#  "Heh, heh. It was nothin'.\n",
#  'What?\n',
#  'Ok, Ok, Pheebs...\n',
#  'Hello.\n',
#  'The girl on the cover with her nipples showing?\n',
#  "(puts down the lasagne) I just... can't do it.\n",
#  "Well, he came in for a massage, and everything was fine until. (A flashback starts Paolo, lying on massage table, moving his hands up Phoebe's legs.)\n",
#  "I can't remember the last time I got a girl to take care of my monkey.\n",
#  'Hey.\n',
#  "Okay, look, this is probably for the best, y'know? Independence. Taking control of your life.  The whole, 'hat' thing.\n",
#  'Oh, I uh, just came by to pick up my skull. Well, not mine, but...Susan: Come in.\n',
#  "(interrupts) No, no, no I don't want to know, don't want to know. Ok, you know, I should probably, I should probably just go.\n",
#  'Green. To the green.\n',
#  "Luisa? Oh my God! Monica! It's Luisa!\n",
#  "Who's Rick?\n",
#  'No, not even close. Forget Vail, forget seeing my family, forget shoop, shoop, shoop.\n',
#  "Yes, yes, it does. Okay, look, the restaurant called, they wanna know if you're gonna be showing up for work?\n",
#  'Hah, no no no no no no no no no no.\n',
#  "Yes, my sister's giving us her place for the weekend.\n",
#  'Yeah, I know! (turns to Chandler) So, what do you think?\n',
#  "Oh, no I don't.\n",
#  "Oh God, oh. Great, Monica, y'know what, you could've called, I have been up here, I've been worried...\n",
#  'Ooh! How about Agamemnon?\n',
#  'Yeah. (They go to the kitchen.)\n',
#  "No, it is me! Y'know, I'm not just the person who needs to fluff the pillows and pay the bills as soon as they come in! Y'know, when I'm with her, I am so much more than that. I'm- I'm Monana!\n",
#  'Okay, gimme my monkey back.\n',
#  "(sarcastic) I don't see why not.\n",
#  "Oh, god, this is great! The plane is gone, so it looks like I'm stuck here with you guys.\n",
#  'Uh, we are here to break up with you.\n',
#  'Uh, Joey..\n',
#  "Oh, well, see, there's this guy she met at the...\n",
#  'Well, I mean, I’m not my sister’s, you know, whatever, and um... I mean, it’s true, we were one egg, once, but err, you know, we’ve grown apart, so, um... I don’t know, why not? Okay.\n',
#  "(picking up a leftover part) What's this?\n",
#  "What's up with the simian?\n",
#  'Yeah. Cushions the blow.\n',
#  "Okay, see, see, you guys, what if we don't get magic beans? I mean, what if all we've got are.. beans?\n",
#  "You're good.\n",
#  'And Mindy, your maid of...?\n',
#  "(entering) How's it going?\n",
#  "Yes, and her boyfriend. But we're celebrating Thanksgiving in December 'cause he is lunar.\n",
#  'Right. No big deal.\n',
#  "It's so that I can spend Thanksgiving with my family. See, every year we go skiing in Vail, and normally my father pays for my ticket, but I sort of started the whole independence thing, you know, which is actually why I took this job.\n",
#  'I read to you.\n',
#  "I'm fine.\n",
#  'It was my first time.\n',
#  "Yeah, I think we're ready for our first course. (Steve sits, Monica brings over a tray) OK, um, these are rot-shrimp ravioli, and celantro pondou sauce... (Steve starts to eat them one by one, quickly)... with just a touch of mints... and... (he finishes)... ginger.\n",
#  "So you don't think I have a, a quality?\n",
#  '(angry) Joey!\n',
#  "They're here already?\n",
#  'Is it me? Is it like I have some sort of beacon that only dogs and men with severe emotional problems can hear?\n',
#  "Isn't this amazing? I mean, I have never made coffee before in my entire life.\n",
#  'Tony?\n',
#  "OK, I have a question. Well, actually, it's not so much a question as.. more of a general wondering... ment.\n",
#  '(deadpan) Please be kidding.\n',
#  'Ah, the forbidden love of a man and his door.\n',
#  'Oh really, so that hysterical phone call I got from a woman at sobbing 3:00 A.M., "I\'ll never have grandchildren, I\'ll never have grandchildren." was what?  A wrong number?\n',
#  'My god, Angela.\n',
#  "You're not an artist.\n",
#  "That's not a question.\n",
#  "(to Joey) So he's calling from Rome. I could do that. Just gotta go to Rome.\n",
#  'Oh my God.\n',
#  'What are you doing?\n',
#  'Alright, now try taking a puff.\n',
#  'What?\n',
#  'I just wanna clarify this: are you outing Mr. Peanut?\n',
#  "Yeah, well, I still got a week left to go in the program, and according to the rules, if I want to get the money I'm not allowed to conduct any... ersonal experiments, if you know what I mean.\n",
#  "Would you excuse me, please? I'm trying to have a date here.\n",
#  '59 seconds. (holds up his watch) Quartz, ha.\n',
#  'What?\n',
#  "Um, that's really your decision, I mean, some people prefer, you know, to take off...oh whoops! You're being naked!\n",
#  "(deals new hand) Boy, you really can't stand to lose, can you? Your whole face is getting red... little veins popping out on your temple...\n",
#  "I don't know... sometimes it doesn't.\n",
#  "I'm having a son. Um...\n",
#  "I don't know. We're talking about whipped fish, Monica. I'm just happy I'm keeping it down, y'know?\n",
#  "Oh, hey, y'know what? Tell them that bone story.\n",
#  'Are you sure?\n',
#  '(tastes it) Well.... it is amouz-ing...\n',
#  '(getting angry) What!!?\n',
#  "See ya.... Waitwait, what's with you?\n",
#  '...As in Mouse?\n',
#  "All right, well, you're right, these are the best oatmeal cookies I've ever had.\n",
#  'I can’t believe you. You still haven’t told that girl she doesn’t have a job yet?\n',
#  'Rachel lost Marcel.\n',
#  'What!?\n',
#  'Yeah, like in a cab...\n',
#  "No problem, ok, mmmwa (kisses Carol) oh, mmmwa (kisses Carol's stomach, then punches Susan's shoulder) Susan... (Ross leaves.)\n",
#  'How do you do that?\n',
#  "Hey Ross, listen, you know that right now, your baby's only this big? (measures about 2 inches with his thumb and index finger) This is your baby. (in baby-like voice) Hi Daddy!\n",
#  "Oh no nonononononnononono, don't go.. (He kisses her and pulls her back down.)\n",
#  'Oh my God! Calling from Rome! (Takes phone) Bon giorno, caro mio.\n',
#  "Ok, Janice. Janice. Hey, Janice. Look, there's no way for me to tell you this. At least there's no new way for me to tell you this. I just don't things are gonna work out.\n",
#  '(mimicking Rachel) Mee mee, mee-mee mee.\n',
#  "The uh, the baby that hasn't been born yet? Wouldn't that mean you're... crazy?\n",
#  'That, you get? That, you get?\n',
#  "Hey, hey, ok, all right, that's it! Get in here. Come on. My god, you guys, I don't believe you. There are children coming into the world in this very building and your negative fighting noises are not the first thing they should be hearing. So just stop all the yelling, just stop it!\n",
#  'Yeah, sorry, the swallowing slowed me down.\n',
#  'Check it out, Giants-Cowboys. (He has a pocket TV)\n',
#  "Hey hey hey! She's on!\n",
#  'When we were?\n',
#  'Hey.\n',
#  "All right! I'm putting it out, I'm putting it out. (He drops it in Phoebe's coffee.)\n",
#  "Ugh. (To another customer that's leaving.) Excuse me, could you give this to that guy over there? (Hands him the coffee pot.) Go ahead. (He does so.) Thank you. (To the gang.) Sorry.  Okay, Las Vegas.\n",
#  'Ooh, ooh, fun! Okay... um, Liam Neeson.\n',
#  "Come on, Ross, you gotta get back in the game here, ok? The Rachel thing's not happening, your ex-wife is a lesbian—I don't think we need a third...\n",
#  '"Warden, in five minutes my pain will be over. But you\'ll have to live with the knowledge that you sent an honest man to die."\n',
#  'It’s mostly just dumb sister stuff, you know, I mean, like, everyone always thought of her as the pretty one, you know... Oh, oh, she was the first one to start walking, even though I did it... later that same day. But, to my parents, by then it was like "yeah, right, well what else is new?"\n',
#  "I couldn't do it.\n",
#  "What're you gonna do?\n",
#  'Okay... Okay.\n',
#  'The most unbelievable thing has happened. Underdog has just gotten away.\n',
#  'Tell me what?\n',
#  'Oh, that is so sweet. (Touched, she puts an arm around her friend and kisses her.) Oh gosh, love you. Insurance?\n',
#  "(as Rachel) Yeah... Yeah, I know it's pretty selfish, but haha, hey, that's me. (Indicating a dish on the table) Why don't you try the hummus?\n",
#  'Well, I guess that’s why they call it psychology, sir.\n',
#  'Yeah!\n',
#  'No!\n',
#  'Sometimes I wish I was a lesbian... (They all stare at him.) Did I say that out loud?\n',
#  'Really.\n',
#  'Joey!!\n',
#  "Barbara! Hi, how are you? (Listens) Uh-huh. (Listens) No, I understand. Yeah. Oh, oh, come on, no, I'm fine. Don't be silly. Yeah... oh, but you know, if-if anything else opens up, plea—Hello? Hello? (hangs up phone, very depressed)\n",
#  'What are you mad at me for?!\n',
#  '"Ooo," what?\n',
#  "No, no, trust, me, it's, it's, it's much better that I know. Uh, I just liked it better before it was better...\n",
#  "Hey, I've been honing!\n",
#  "Why did I 'woo-hoo'? I mean, what was I hoping would happen? That-that he'd turn round and say 'I love that sound, I must have you now'?\n",
#  "Well, y'know, monogamy can be a, uh, tricky concept. I mean, anthropologically speaking-\n",
#  'Alright. Well then how about I call your supervisor, and I tell her that you shot my friend in the ass with a dart?\n',
#  'Thanks, you can just put it on the table.\n',
#  'Monica, in or out?\n',
#  "Um, I'm not actually Amish.\n",
#  "So... What's the deal with umm, you and Joey?\n",
#  '(entering from her room) Okay, coming!\n',
#  'Yeah, it was really hard.\n',
#  'You guys okay?\n',
#  'Get him! GET HIM! Get him! Get- YESSS! Not laughing now, are ya pal!\n',
#  'Yeah. (They go to the kitchen.)\n',
#  'Hon, you gotta talk to Joey.\n',
#  "Hell no, we'll pay!\n",
#  "...I'm his (mumbles)\n",
#  'No, you are not. We tell you stuff.\n',
#  "Alright, so I'm back in high school, I'm standing in the middle of the cafeteria, and I realize I am totally naked.\n",
#  '(pulls Monica back) ...and I really think it should be me.\n',
#  "Well, I'm- I'm showering.\n",
#  'For the ride.\n',
#  'You.\n',
#  "Oh. (pause) Hey, who's Carl?\n",
#  'I knew.\n',
#  ...]

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
oov_tok = "<OOV>"


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

# %%
testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_review(padded[1]))
print(training_sentences[1])
# Out:
# ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? yes way to go man chandler and ross hug something crunches in ross' shirt pocket still got the egg huh
# Yes! Way to go, man! (Chandler and Ross hug. Something crunches in Ross' shirt pocket.) Still got the egg, huh?

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 120, 16)           160000
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1920)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 6)                 11526
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 171,533
# Trainable params: 171,533
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 10
model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Train on 7278 samples, validate on 2426 samples
# Epoch 1/10
# 7278/7278 [==============================] - 1s 91us/sample - loss: -21.0478 - accuracy: 0.1315 - val_loss: -26.0078 - val_accuracy: 0.1356
# Epoch 2/10
# 7278/7278 [==============================] - 0s 59us/sample - loss: -25.7456 - accuracy: 0.1312 - val_loss: -26.0154 - val_accuracy: 0.1356
# Epoch 3/10
# 7278/7278 [==============================] - 0s 58us/sample - loss: -25.7492 - accuracy: 0.1312 - val_loss: -26.0167 - val_accuracy: 0.1356
# Epoch 4/10
# 7278/7278 [==============================] - 0s 62us/sample - loss: -25.7511 - accuracy: 0.1312 - val_loss: -26.0189 - val_accuracy: 0.1356
# Epoch 5/10
# 7278/7278 [==============================] - 0s 59us/sample - loss: -25.7540 - accuracy: 0.1312 - val_loss: -26.0191 - val_accuracy: 0.1356
# Epoch 6/10
# 7278/7278 [==============================] - 0s 60us/sample - loss: -25.7587 - accuracy: 0.1315 - val_loss: -26.0173 - val_accuracy: 0.1360
# Epoch 7/10
# 7278/7278 [==============================] - 0s 54us/sample - loss: -25.7619 - accuracy: 0.1319 - val_loss: -26.0174 - val_accuracy: 0.1360
# Epoch 8/10
# 7278/7278 [==============================] - 0s 57us/sample - loss: -25.7667 - accuracy: 0.1319 - val_loss: -26.0201 - val_accuracy: 0.1360
# Epoch 9/10
# 7278/7278 [==============================] - 0s 57us/sample - loss: -25.7733 - accuracy: 0.1326 - val_loss: -26.0226 - val_accuracy: 0.1364
# Epoch 10/10
# 7278/7278 [==============================] - 0s 60us/sample - loss: -25.7771 - accuracy: 0.1330 - val_loss: -26.0258 - val_accuracy: 0.1360

# %%
e = model.layers[0]
weights = e.get_weights()[0]
print(weights.shape) # shape: (vocab_size, embedding_dim)
# Out:
# (10000, 16)

# %%
len(reverse_word_index)
# Out:
# 4597

# %%
import io

out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')

for word_num in range(1, 4597):
  word = reverse_word_index[word_num]
  embeddings = weights[word_num]
  out_m.write(word + "\n")
  out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")
out_v.close()
out_m.close()

# %%
try:
  from google.colab import files
except ImportError:
  pass
else:
  files.download('vecs.tsv')
  files.download('meta.tsv')

# %%
sentence = "You’re gonna mess it up let me do it."
sequence = tokenizer.texts_to_sequences(sentence)
print(sequence)
# Out:
# [[927], [1005], [1882], [1], [1], [1], [], [1], [1005], [1881], [1881], [6], [], [1589], [1], [1], [1], [], [2], [4126], [], [1882], [1], [], [1], [1], [4126], [], [1589], [1], [], [2243], [1005], [], [2], [4126], []]
